# %%
# ============================================================
#  YOLO Scratch Training — DeepFashion2 Top-5 Categories
#  Native DF2 Dataset  |  Dual-GPU (T4×2)
#  Task 3.2: Detection + Segmentation
# ============================================================

# ─── 0. INSTALLATION ────────────────────────────────────────
import subprocess, sys

def _install(pkg: str) -> None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])

for _pkg in [
    "ultralytics", "scikit-learn", "matplotlib", "seaborn",
    "Pillow", "tqdm", "pyyaml", "opencv-python-headless", "pandas",
]:
    _install(_pkg)

# ─── 1. STDLIB / THIRD-PARTY IMPORTS ────────────────────────
import json
import logging
import multiprocessing as mp
import random
import shutil
import time
import warnings
from collections import defaultdict
from concurrent.futures import ProcessPoolExecutor, as_completed
from pathlib import Path

import cv2
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import yaml
from PIL import Image
from sklearn.metrics import auc, roc_curve
from tqdm import tqdm
from ultralytics import YOLO

warnings.filterwarnings("ignore", category=FutureWarning)

# ─── 2. LOGGING SETUP ───────────────────────────────────────
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s  [%(levelname)-8s]  %(name)s — %(message)s",
    datefmt="%H:%M:%S",
)
ROOT_LOG = logging.getLogger("yolo_fashion")


# ════════════════════════════════════════════════════════════
#  CLASS 1 — DatasetConfig
# ════════════════════════════════════════════════════════════
class DatasetConfig:
    """
    Class mapping contract
    ─────────────────────
    DF2 cat_id  →  YOLO idx  →  class name
    ─────────────────────────────────────────
         1      →     0     →  short_sleeve_top
         8      →     1     →  trousers
         7      →     2     →  shorts
         2      →     3     →  long_sleeve_top
         9      →     4     →  skirt

    Semantic mask convention:
        pixel 0  = background
        pixel N  = foreground (N = yolo_idx + 1)
    """

    _DF2_REGISTRY: dict = {
        1: "short_sleeve_top",  2: "long_sleeve_top",
        3: "short_sleeve_outwear", 4: "long_sleeve_outwear",
        5: "vest",              6: "sling",
        7: "shorts",            8: "trousers",
        9: "skirt",            10: "short_sleeve_dress",
        11: "long_sleeve_dress", 12: "vest_dress",
        13: "sling_dress",
    }

    def __init__(self) -> None:
        self._log = logging.getLogger(f"{ROOT_LOG.name}.config")

        # ── Paths ────────────────────────────────────────────
        _base = Path(
            "/kaggle/input/datasets/shubhranilbasak"
            "/vr-trimmed-dataset/Trimmed-vr-dataset"
        )

        self.annos_base: dict = {
            "train"      : _base / "DeepFashion2_Top5_train" / "annos",
            "validation" : _base / "DeepFashion2_Top5_val"   / "annos",
        }
        self.img_base: dict = {
            "train"      : _base / "DeepFashion2_Top5_train" / "images",
            "validation" : _base / "DeepFashion2_Top5_val"   / "images",
        }

        self.work_dir    = Path("/kaggle/working/yolo_fashion_scratch")
        self.dataset_dir = self.work_dir / "dataset"
        self.results_dir = self.work_dir / "results"
        for _d in [self.work_dir, self.dataset_dir, self.results_dir]:
            _d.mkdir(parents=True, exist_ok=True)

        # ── Class Mapping ────────────────────────────────────
        self.top5_cat_ids: list = [1, 8, 7, 2, 9]
        self.cat_id_to_yolo: dict = {
            cat_id: yolo_idx
            for yolo_idx, cat_id in enumerate(self.top5_cat_ids)
        }
        self.yolo_to_name: dict = {
            yolo_idx: self._DF2_REGISTRY[cat_id]
            for yolo_idx, cat_id in enumerate(self.top5_cat_ids)
        }
        self.num_classes: int = len(self.top5_cat_ids)

        # ── GPU Setup ────────────────────────────────────────
        self.num_gpus   = torch.cuda.device_count()
        self.gpu_names  = [torch.cuda.get_device_name(i) for i in range(self.num_gpus)]
        self.device_str = (
            ",".join(str(i) for i in range(self.num_gpus))
            if self.num_gpus > 0 else "cpu"
        )
        self.infer_device  = "0" if self.num_gpus > 0 else "cpu"
        self.num_workers   = min(8, mp.cpu_count())
        self.prep_workers  = max(1, mp.cpu_count() - 1)

        # ── Model ────────────────────────────────────────────
        self.base_weights   = "yolov8n-seg.pt"   # architecture only — no pretrained weights loaded
        self.infer_batch_sz = 16

        # ── Training Hyperparameters ─────────────────────────
        # ✅ SCRATCH TRAINING — key differences vs transfer learning:
        #    pretrained=False  → random weight initialisation
        #    freeze=0          → all layers trainable from the start
        #    lr0=0.01          → higher LR (no pretrained weights to preserve)
        #    warmup_epochs=3   → longer warmup since starting from random init
        #    epochs=15         → same as requested
        self.train_hp: dict = {
            "epochs"        : 15,
            "imgsz"         : 640,
            "batch"         : 32,
            "workers"       : self.num_workers,
            "device"        : self.device_str,
            "patience"      : 5,
            "lr0"           : 0.01,       # ← higher than fine-tuning (was 1e-5)
            "lrf"           : 0.01,
            "momentum"      : 0.937,
            "weight_decay"  : 0.0005,
            "warmup_epochs" : 3,          # ← longer warmup (was 1)
            "cos_lr"        : True,
            "amp"           : True,
            "cache"         : "disk",
            "augment"       : True,
            "mosaic"        : 1.0,
            "mixup"         : 0.1,
            "copy_paste"    : 0.0,
            "degrees"       : 10.0,
            "translate"     : 0.1,
            "scale"         : 0.5,
            "fliplr"        : 0.5,
            "hsv_h"         : 0.015,
            "hsv_s"         : 0.7,
            "hsv_v"         : 0.4,
            "verbose"       : True,
            "plots"         : True,
            "save"          : True,
            "project"       : str(self.results_dir),
            "name"          : "yolo_fashion_scratch",
            "exist_ok"      : True,
            "pretrained"    : False,      # ← random init (was True)
            "freeze"        : 0,          # ← nothing frozen (was 10)
        }
        self.yaml_path: Path = self.dataset_dir / "dataset.yaml"

    def generate_yaml(self) -> Path:
        cfg = {
            "path"  : str(self.dataset_dir),
            "train" : "images/train",
            "val"   : "images/validation",
            "nc"    : self.num_classes,
            "names" : [self.yolo_to_name[i] for i in range(self.num_classes)],
        }
        with open(self.yaml_path, "w") as fh:
            yaml.dump(cfg, fh, default_flow_style=False)
        self._log.info("dataset.yaml → %s", self.yaml_path)
        self._log.info("Classes (%d): %s", self.num_classes, cfg["names"])
        return self.yaml_path

    def log_summary(self) -> None:
        self._log.info("GPU inventory: %d  %s", self.num_gpus, self.gpu_names)
        self._log.info("Devices — train: %s  infer: %s", self.device_str, self.infer_device)
        class_df = pd.DataFrame([
            {"yolo_idx": yi, "df2_cat": self.top5_cat_ids[yi],
             "sem_pixel": yi + 1, "name": self.yolo_to_name[yi]}
            for yi in range(self.num_classes)
        ])
        self._log.info("Class mapping:\n%s", class_df.to_string(index=False))
        hp_df = pd.DataFrame(list(self.train_hp.items()), columns=["parameter", "value"])
        self._log.info("Hyperparameters:\n%s", hp_df.to_string(index=False))


# ════════════════════════════════════════════════════════════
#  MODULE-LEVEL WORKER
# ════════════════════════════════════════════════════════════
def _convert_record(args: tuple) -> bool:
    anno_fp_str, img_dir_str, cat_id_to_yolo, img_out_str, lbl_out_str, mask_out_str = args

    anno_fp  = Path(anno_fp_str)
    img_dir  = Path(img_dir_str)
    img_out  = Path(img_out_str)
    lbl_out  = Path(lbl_out_str)
    mask_out = Path(mask_out_str)

    stem   = anno_fp.stem
    img_fp = img_dir / f"{stem}.jpg"
    if not img_fp.exists():
        img_fp = img_dir / f"{stem}.png"
    if not img_fp.exists():
        return False

    try:
        with open(anno_fp) as fh:
            anno = json.load(fh)
    except Exception:
        return False

    valid_items = []
    for key, item in anno.items():
        if not key.startswith("item"):
            continue
        cat_id = item.get("category_id", -1)
        if cat_id not in cat_id_to_yolo:
            continue
        segs     = item.get("segmentation", [[]])
        raw_poly = segs[0] if segs else []
        valid_items.append({
            "yolo_cls": cat_id_to_yolo[cat_id],
            "polygon" : raw_poly,
        })

    if not valid_items:
        return False

    try:
        pil_img      = Image.open(img_fp)
        img_w, img_h = pil_img.size
    except Exception:
        return False

    sem_mask    = np.zeros((img_h, img_w), dtype=np.uint8)
    label_lines = []

    for item in valid_items:
        yolo_cls = item["yolo_cls"]
        sem_idx  = yolo_cls + 1
        raw_poly = item["polygon"]

        if len(raw_poly) < 6:
            continue

        pts_abs = [
            [int(round(raw_poly[i])), int(round(raw_poly[i + 1]))]
            for i in range(0, len(raw_poly) - 1, 2)
        ]
        pts_np = np.array(pts_abs, dtype=np.int32).reshape((-1, 1, 2))
        pts_np[..., 0] = np.clip(pts_np[..., 0], 0, img_w - 1)
        pts_np[..., 1] = np.clip(pts_np[..., 1], 0, img_h - 1)
        cv2.fillPoly(sem_mask, [pts_np], int(sem_idx))

        norm_coords = []
        for i in range(0, len(raw_poly) - 1, 2):
            norm_coords.append(max(0.0, min(1.0, raw_poly[i]     / img_w)))
            norm_coords.append(max(0.0, min(1.0, raw_poly[i + 1] / img_h)))

        pts_str = " ".join(f"{v:.6f}" for v in norm_coords)
        label_lines.append(f"{yolo_cls} {pts_str}")

    if not label_lines:
        return False

    (lbl_out  / f"{stem}.txt").write_text("\n".join(label_lines))
    Image.fromarray(sem_mask).save(mask_out / f"{stem}.png")

    dst = img_out / img_fp.name
    if not dst.exists():
        shutil.copy2(img_fp, dst)

    return True


# ════════════════════════════════════════════════════════════
#  CLASS 2 — YoloDataBuilder
# ════════════════════════════════════════════════════════════
class YoloDataBuilder:

    def __init__(self, config: DatasetConfig) -> None:
        self.cfg  = config
        self._log = logging.getLogger(f"{ROOT_LOG.name}.builder")

    def build_all(self) -> tuple:
        n_train = self._build_split("train")
        n_val   = self._build_split("validation")
        self._log.info("Dataset build complete.  train=%d  val=%d", n_train, n_val)
        return n_train, n_val

    def compute_class_weights(self) -> np.ndarray:
        lbl_dir = self.cfg.dataset_dir / "labels" / "train"
        counts  = np.zeros(self.cfg.num_classes, dtype=np.float64)
        for fp in lbl_dir.glob("*.txt"):
            for line in fp.read_text().splitlines():
                parts = line.strip().split()
                if parts:
                    counts[int(parts[0])] += 1
        counts  = np.where(counts == 0, 1.0, counts)
        weights = 1.0 / counts
        weights = weights / weights.sum() * self.cfg.num_classes
        df = pd.DataFrame({
            "yolo_idx"  : range(self.cfg.num_classes),
            "class_name": [self.cfg.yolo_to_name[i] for i in range(self.cfg.num_classes)],
            "count"     : counts,
            "weight"    : weights,
        })
        self._log.info("Class weights:\n%s", df.round(4).to_string(index=False))
        return weights

    def _build_split(self, split_name: str) -> int:
        img_out  = self.cfg.dataset_dir / "images"    / split_name
        lbl_out  = self.cfg.dataset_dir / "labels"    / split_name
        mask_out = self.cfg.dataset_dir / "seg_masks" / split_name
        for _d in [img_out, lbl_out, mask_out]:
            _d.mkdir(parents=True, exist_ok=True)

        annos_dir  = self.cfg.annos_base[split_name]
        anno_files = sorted(annos_dir.glob("*.json"))
        img_dir    = self.cfg.img_base[split_name]

        self._log.info(
            "[%s] %d annotation files found in %s",
            split_name, len(anno_files), annos_dir,
        )

        worker_args = [
            (str(af), str(img_dir), self.cfg.cat_id_to_yolo,
             str(img_out), str(lbl_out), str(mask_out))
            for af in anno_files
        ]

        written = skipped = 0
        with ProcessPoolExecutor(max_workers=self.cfg.prep_workers) as executor:
            future_map = {
                executor.submit(_convert_record, arg): arg
                for arg in worker_args
            }
            with tqdm(total=len(future_map), desc=f"  Building [{split_name}]") as pbar:
                for future in as_completed(future_map):
                    if future.result():
                        written += 1
                    else:
                        skipped += 1
                    pbar.update(1)

        self._log.info("[%s] written=%d  skipped=%d", split_name, written, skipped)
        return written


# ════════════════════════════════════════════════════════════
#  CLASS 3 — YoloTrainer
# ════════════════════════════════════════════════════════════
class YoloTrainer:

    def __init__(self, config: DatasetConfig) -> None:
        self.cfg      = config
        self._log     = logging.getLogger(f"{ROOT_LOG.name}.trainer")
        self.model    = None
        self.save_dir: Path = None

    def load_pretrained(self) -> YOLO:
        self.model = YOLO(self.cfg.base_weights)

        self._epoch_times: list  = []
        self._epoch_start: float = 0.0

        self.model.add_callback("on_train_epoch_start", self._cb_epoch_start)
        self.model.add_callback("on_train_epoch_end",   self._cb_epoch_end)

        n_params = sum(p.numel() for p in self.model.model.parameters())
        self._log.info("Loaded %s  (%s parameters)", self.cfg.base_weights, f"{n_params:,}")
        self._log.info("Strategy: SCRATCH — all layers randomly initialised, nothing frozen")
        self._log.info("Epoch-timing callbacks registered.")
        return self.model

    def train(self, yaml_path: Path) -> Path:
        hp = self.cfg.train_hp
        hp_df = pd.DataFrame(list(hp.items()), columns=["parameter", "value"])
        self._log.info("Training configuration:\n%s", hp_df.to_string(index=False))

        t_start   = time.time()
        results   = self.model.train(data=str(yaml_path), **hp)
        elapsed_s = time.time() - t_start

        self._log.info(
            "Training finished in %.1fs  (%dm %ds)",
            elapsed_s, int(elapsed_s // 60), int(elapsed_s % 60),
        )

        self.save_dir = self._resolve_save_dir(results)
        best_pt       = self.save_dir / "weights" / "best.pt"

        if not best_pt.exists():
            last_pt = self.save_dir / "weights" / "last.pt"
            if last_pt.exists():
                best_pt = last_pt
                self._log.warning("best.pt absent — falling back to last.pt")

        self._log.info("Save dir   : %s", self.save_dir)
        self._log.info("Best model : %s", best_pt)
        self._log_epoch_table()
        return best_pt

    def _resolve_save_dir(self, results) -> Path:
        if results is not None and hasattr(results, "save_dir"):
            return Path(results.save_dir)
        if getattr(self.model, "trainer", None) is not None:
            if hasattr(self.model.trainer, "save_dir"):
                return Path(self.model.trainer.save_dir)
        named = Path(self.cfg.train_hp["project"]) / self.cfg.train_hp["name"]
        if named.exists():
            return named
        candidates = [d for d in Path(self.cfg.train_hp["project"]).iterdir() if d.is_dir()]
        if candidates:
            return max(candidates, key=lambda d: d.stat().st_mtime)
        raise FileNotFoundError(
            f"Cannot locate training output under {self.cfg.train_hp['project']}"
        )

    def _cb_epoch_start(self, trainer) -> None:
        self._epoch_start = time.time()

    def _cb_epoch_end(self, trainer) -> None:
        duration = time.time() - self._epoch_start
        self._epoch_times.append(duration)
        self._log.info(
            "Epoch %d/%d  —  wall-clock time: %.1fs  (%dm %ds)",
            trainer.epoch + 1, trainer.epochs,
            duration, int(duration // 60), int(duration % 60),
        )

    def _log_epoch_table(self) -> None:
        csv_path = self.save_dir / "results.csv"
        if not csv_path.exists():
            self._log.warning("results.csv not found — epoch log unavailable")
            return
        df = pd.read_csv(csv_path)
        df.columns = [c.strip() for c in df.columns]
        if self._epoch_times:
            n_rows = min(len(df), len(self._epoch_times))
            df.loc[: n_rows - 1, "epoch_time_s"] = [
                round(t, 1) for t in self._epoch_times[:n_rows]
            ]
            total_s = sum(self._epoch_times)
            self._log.info(
                "Total epoch wall-clock time: %.1fs  (%dm %ds)  | mean per epoch: %.1fs",
                total_s, int(total_s // 60), int(total_s % 60),
                total_s / len(self._epoch_times),
            )
        self._log.info(
            "Epoch-by-epoch training log:\n%s", df.round(4).to_string(index=False)
        )


# ════════════════════════════════════════════════════════════
#  CLASS 4 — YoloEvaluator
# ════════════════════════════════════════════════════════════
class YoloEvaluator:

    IOU_THRESHOLDS: np.ndarray = np.arange(0.5, 1.0, 0.05)

    def __init__(self, config: DatasetConfig, best_model_path: Path) -> None:
        self.cfg  = config
        self._log = logging.getLogger(f"{ROOT_LOG.name}.evaluator")

        self.model = YOLO(str(best_model_path))
        self._log.info("Best model loaded from %s", best_model_path)

        self.val_img_dir  = config.dataset_dir / "images"    / "validation"
        self.val_lbl_dir  = config.dataset_dir / "labels"    / "validation"
        self.val_mask_dir = config.dataset_dir / "seg_masks" / "validation"

        self.val_images: list = (
            sorted(self.val_img_dir.glob("*.jpg"))
            + sorted(self.val_img_dir.glob("*.png"))
        )
        self._log.info("Validation images available: %d", len(self.val_images))
        self._reset_accumulators()

        self._det_df: pd.DataFrame = None
        self._seg_df: pd.DataFrame = None
        self._roc_df: pd.DataFrame = None

    def run_inference(self) -> None:
        bs      = self.cfg.infer_batch_sz
        batches = [self.val_images[i: i + bs] for i in range(0, len(self.val_images), bs)]
        self._log.info(
            "Batched GPU inference — %d images, batch_size=%d, device=%s",
            len(self.val_images), bs, self.cfg.infer_device,
        )
        for batch_fps in tqdm(batches, desc="GPU inference"):
            batch_preds = self.model.predict(
                source  = [str(fp) for fp in batch_fps],
                imgsz   = self.cfg.train_hp["imgsz"],
                device  = self.cfg.infer_device,
                verbose = False,
                conf    = 0.1,
                stream  = False,
            )
            for img_fp, res in zip(batch_fps, batch_preds):
                self._accumulate_image(img_fp, res)
        self._log.info("Inference and metric accumulation complete.")

    def compute_detection_metrics(self) -> pd.DataFrame:
        n        = self.cfg.num_classes
        ap_table = np.zeros((n, len(self.IOU_THRESHOLDS)))
        for ci in range(n):
            for ti, iou_t in enumerate(self.IOU_THRESHOLDS):
                ap_table[ci, ti] = self._compute_ap(
                    self.per_class_preds[ci], self.per_class_gt_cnt[ci], iou_t,
                )
        self._ap_table = ap_table
        ap75_idx = min(5, len(self.IOU_THRESHOLDS) - 1)
        rows = []
        for ci in range(n):
            P, R, F1 = self._prf_at_conf(self.per_class_preds[ci], self.per_class_gt_cnt[ci])
            rows.append({
                "class"        : self.cfg.yolo_to_name[ci],
                "AP@0.50"      : round(ap_table[ci, 0],        4),
                "AP@0.75"      : round(ap_table[ci, ap75_idx], 4),
                "mAP@[.5:.95]" : round(ap_table[ci].mean(),    4),
                "Precision"    : round(P,  4),
                "Recall"       : round(R,  4),
                "F1"           : round(F1, 4),
            })
        df = pd.DataFrame(rows)
        macro = {
            "class"        : "Macro Average",
            "AP@0.50"      : round(df["AP@0.50"].mean(),       4),
            "AP@0.75"      : round(df["AP@0.75"].mean(),       4),
            "mAP@[.5:.95]" : round(df["mAP@[.5:.95]"].mean(), 4),
            "Precision"    : round(df["Precision"].mean(),     4),
            "Recall"       : round(df["Recall"].mean(),        4),
            "F1"           : round(df["F1"].mean(),            4),
        }
        self._det_df = pd.concat([df, pd.DataFrame([macro])], ignore_index=True)
        self._log.info("Detection metrics:\n%s", self._det_df.to_string(index=False))
        return self._det_df

    def compute_segmentation_metrics(self) -> pd.DataFrame:
        rows = []
        for ci in range(self.cfg.num_classes):
            ious  = self.sem_iou_per_class[ci]
            dices = self.sem_dice_per_class[ci]
            rows.append({
                "class"    : self.cfg.yolo_to_name[ci],
                "sem_pixel": ci + 1,
                "mIoU"     : round(np.mean(ious)  if ious  else 0.0, 4),
                "Dice"     : round(np.mean(dices) if dices else 0.0, 4),
                "n_images" : len(ious),
            })
        df = pd.DataFrame(rows)
        macro = {
            "class"    : "Macro Average",
            "sem_pixel": "—",
            "mIoU"     : round(df["mIoU"].mean(), 4),
            "Dice"     : round(df["Dice"].mean(), 4),
            "n_images" : "—",
        }
        self._seg_df = pd.concat([df, pd.DataFrame([macro])], ignore_index=True)
        self._log.info(
            "Segmentation metrics (background pixel=0 excluded):\n%s",
            self._seg_df.to_string(index=False),
        )
        return self._seg_df

    def compute_roc_auc(self, output_dir: Path) -> pd.DataFrame:
        n   = self.cfg.num_classes
        fig, axes = plt.subplots(1, n, figsize=(5 * n, 4))
        axes = [axes] if n == 1 else list(axes)
        rows = []
        for ci in range(n):
            yt   = np.array(self.y_true_det[ci])
            ys   = np.array(self.y_score_det[ci])
            ax   = axes[ci]
            name = self.cfg.yolo_to_name[ci]
            if yt.sum() == 0 or (1 - yt).sum() == 0:
                roc_auc = float("nan")
                ax.set_title(f"{name}\n(AUC undefined)")
            else:
                fpr, tpr, _ = roc_curve(yt, ys)
                roc_auc     = auc(fpr, tpr)
                ax.plot(fpr, tpr, lw=2, label=f"AUC = {roc_auc:.3f}")
                ax.plot([0, 1], [0, 1], "k--", lw=1)
                ax.set_xlabel("FPR"); ax.set_ylabel("TPR")
                ax.legend(); ax.set_xlim(0, 1); ax.set_ylim(0, 1)
                ax.set_title(name)
            rows.append({"class": name, "AUC": round(roc_auc, 4)})
        plt.suptitle("ROC Curves — Detection (per class)", fontsize=14)
        plt.tight_layout()
        roc_path = output_dir / "roc_curves_detection.png"
        plt.savefig(roc_path, dpi=120, bbox_inches="tight")
        plt.show()
        df = pd.DataFrame(rows)
        macro = {"class": "Macro Average", "AUC": round(float(np.nanmean(df["AUC"])), 4)}
        self._roc_df = pd.concat([df, pd.DataFrame([macro])], ignore_index=True)
        self._log.info("ROC AUC:\n%s", self._roc_df.to_string(index=False))
        self._log.info("ROC figure saved → %s", roc_path)
        return self._roc_df

    def plot_training_curves(self, trainer_save_dir: Path) -> None:
        csv_path = trainer_save_dir / "results.csv"
        if not csv_path.exists():
            self._log.warning("results.csv missing — skipping training curves")
            return
        df = pd.read_csv(csv_path)
        df.columns = [c.strip() for c in df.columns]
        metric_cols = [
            c for c in df.columns
            if any(k in c.lower() for k in ["loss", "map", "precision", "recall"])
        ]
        n_cols = min(4, len(metric_cols))
        n_rows = max(1, (len(metric_cols) + n_cols - 1) // n_cols)
        fig, axs = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
        axs      = np.array(axs).flatten()
        x_vals   = df.get("epoch", range(len(df)))
        for i, col in enumerate(metric_cols):
            axs[i].plot(x_vals, df[col])
            axs[i].set_title(col)
            axs[i].set_xlabel("Epoch")
        for j in range(i + 1, len(axs)):
            axs[j].axis("off")
        plt.suptitle("Training Metrics Over Epochs", fontsize=14)
        plt.tight_layout()
        out_path = self.cfg.results_dir / "training_curves.png"
        plt.savefig(out_path, dpi=120, bbox_inches="tight")
        plt.show()
        self._log.info("Training curves saved → %s", out_path)

    def plot_qualitative_predictions(self, n_samples: int = 6) -> None:
        sample_fps   = random.sample(self.val_images, min(n_samples, len(self.val_images)))
        qual_results = self.model.predict(
            source  = [str(fp) for fp in sample_fps],
            imgsz   = self.cfg.train_hp["imgsz"],
            device  = self.cfg.infer_device,
            verbose = False,
            conf    = 0.25,
        )
        cmap = plt.cm.get_cmap("tab10", self.cfg.num_classes)
        fig, axes = plt.subplots(2, 3, figsize=(18, 12))
        axes      = axes.flatten()
        for ax_idx, (fp, res) in enumerate(zip(sample_fps, qual_results)):
            ax     = axes[ax_idx]
            img_np = np.array(Image.open(fp).convert("RGB"))
            ax.imshow(img_np)
            if res.boxes is not None:
                boxes   = res.boxes
                masks_r = res.masks
                for idx in range(len(boxes)):
                    cls_id = int(boxes.cls[idx])
                    conf   = float(boxes.conf[idx])
                    xyxy   = boxes.xyxy[idx].cpu().numpy()
                    color  = cmap(cls_id)
                    ax.add_patch(patches.Rectangle(
                        (xyxy[0], xyxy[1]), xyxy[2] - xyxy[0], xyxy[3] - xyxy[1],
                        linewidth=2, edgecolor=color, facecolor="none",
                    ))
                    ax.text(
                        xyxy[0], xyxy[1] - 4,
                        f"{self.cfg.yolo_to_name.get(cls_id, '?')}  {conf:.2f}",
                        color="white", fontsize=8,
                        bbox=dict(facecolor=color, alpha=0.7, pad=1),
                    )
                    if masks_r is not None and idx < len(masks_r.xy):
                        poly_pts = np.array(masks_r.xy[idx])
                        if len(poly_pts) >= 3:
                            ax.add_patch(patches.Polygon(
                                poly_pts, closed=True, facecolor=color, alpha=0.35,
                            ))
            ax.axis("off")
            ax.set_title(fp.stem, fontsize=9)
        plt.suptitle("YOLO Predictions on Validation Set", fontsize=14)
        plt.tight_layout()
        vis_path = self.cfg.results_dir / "qualitative_predictions.png"
        plt.savefig(vis_path, dpi=120, bbox_inches="tight")
        plt.show()
        self._log.info("Qualitative visualisation saved → %s", vis_path)

    def plot_per_class_bar_chart(self) -> None:
        n           = self.cfg.num_classes
        names_short = [self.cfg.yolo_to_name[i][:13] for i in range(n)]
        det = self._det_df[self._det_df["class"] != "Macro Average"].reset_index(drop=True)
        seg = self._seg_df[self._seg_df["class"] != "Macro Average"].reset_index(drop=True)
        x, w = np.arange(n), 0.15
        fig, ax = plt.subplots(figsize=(max(10, 2 * n), 5))
        ax.bar(x - 2 * w, det["Precision"],   w, label="Precision",  color="steelblue")
        ax.bar(x -     w, det["Recall"],       w, label="Recall",     color="darkorange")
        ax.bar(x,         det["F1"],            w, label="F1",         color="green")
        ax.bar(x +     w, det["mAP@[.5:.95]"], w, label="mAP@.5:.95", color="red")
        ax.bar(x + 2 * w, seg["mIoU"],          w, label="mIoU",       color="purple")
        ax.set_xticks(x)
        ax.set_xticklabels(names_short, rotation=30, ha="right")
        ax.set_ylim(0, 1.05)
        ax.set_ylabel("Score")
        ax.set_title("Per-Class Metrics — Detection & Segmentation")
        ax.legend(loc="upper right", fontsize=8)
        plt.tight_layout()
        bar_path = self.cfg.results_dir / "per_class_metrics.png"
        plt.savefig(bar_path, dpi=120, bbox_inches="tight")
        plt.show()
        self._log.info("Per-class bar chart saved → %s", bar_path)

    def print_final_summary(self, n_train: int, n_val: int) -> None:
        cfg = self.cfg
        hp  = cfg.train_hp
        self._log.info("=== FINAL METRICS SUMMARY ===")
        self._log.info(
            "GPU(s): %d× %s  |  train=%d  val=%d  epochs=%d  imgsz=%d  batch=%d",
            cfg.num_gpus, cfg.gpu_names[0] if cfg.gpu_names else "CPU",
            n_train, n_val, hp["epochs"], hp["imgsz"], hp["batch"],
        )
        summary = (
            self._det_df
            .merge(self._seg_df[["class", "mIoU", "Dice"]], on="class", how="left")
            .merge(self._roc_df, on="class", how="left")
        )
        self._log.info("Full per-class summary:\n%s", summary.to_string(index=False))
        self._log.info("Semantic mask pixel legend:")
        self._log.info("  pixel 0 = background (unannotated)")
        for ci in range(cfg.num_classes):
            self._log.info(
                "  pixel %d = %s  (YOLO class %d)", ci + 1, cfg.yolo_to_name[ci], ci,
            )
        self._log.info("Outputs saved to: %s", cfg.results_dir)

    # ── Private: accumulators ─────────────────────────────────

    def _reset_accumulators(self) -> None:
        n = self.cfg.num_classes
        self.per_class_preds:    dict = {c: [] for c in range(n)}
        self.per_class_gt_cnt:   dict = {c: 0  for c in range(n)}
        self.sem_iou_per_class:  dict = {c: [] for c in range(n)}
        self.sem_dice_per_class: dict = {c: [] for c in range(n)}
        self.y_true_det:         dict = {c: [] for c in range(n)}
        self.y_score_det:        dict = {c: [] for c in range(n)}

    def _accumulate_image(self, img_fp: Path, res) -> None:
        pil_img = Image.open(img_fp)
        W, H    = pil_img.size
        stem    = img_fp.stem
        gts     = self._load_ground_truth(stem, W, H)
        if not gts:
            return
        gt_labels_set = {g["label"] for g in gts}
        gt_by_cls     = defaultdict(list)
        for g in gts:
            gt_by_cls[g["label"]].append(g)
            self.per_class_gt_cnt[g["label"]] += 1
        preds = self._extract_preds(res)
        pred_max_conf = defaultdict(float)
        for p in preds:
            pred_max_conf[p["cls"]] = max(pred_max_conf[p["cls"]], p["conf"])
        for c in range(self.cfg.num_classes):
            self.y_true_det[c].append(1 if c in gt_labels_set else 0)
            self.y_score_det[c].append(pred_max_conf.get(c, 0.0))
        for p in sorted(preds, key=lambda x: x["conf"], reverse=True):
            c        = p["cls"]
            best_iou = max(
                (self._iou_boxes(p["bbox"], gt["bbox"]) for gt in gt_by_cls.get(c, [])),
                default=0.0,
            )
            self.per_class_preds[c].append((p["conf"], best_iou))
        gt_mask_fp = self.val_mask_dir / f"{stem}.png"
        if not gt_mask_fp.exists():
            return
        gt_sem   = np.array(Image.open(gt_mask_fp))
        pred_sem = np.zeros((H, W), dtype=np.uint8)
        for p in preds:
            if p["conf"] < 0.25 or p["poly"] is None:
                continue
            sem_idx = p["cls"] + 1
            poly_np = np.array(p["poly"], dtype=np.int32).reshape((-1, 1, 2))
            poly_np[..., 0] = np.clip(poly_np[..., 0], 0, W - 1)
            poly_np[..., 1] = np.clip(poly_np[..., 1], 0, H - 1)
            cv2.fillPoly(pred_sem, [poly_np], int(sem_idx))
        for ci in range(self.cfg.num_classes):
            sem_idx  = ci + 1
            gt_bin   = (gt_sem   == sem_idx).astype(np.uint8)
            pred_bin = (pred_sem == sem_idx).astype(np.uint8)
            if gt_bin.sum() == 0:
                continue
            self.sem_iou_per_class[ci].append(self._iou_masks(pred_bin, gt_bin))
            self.sem_dice_per_class[ci].append(self._dice_masks(pred_bin, gt_bin))

    def _load_ground_truth(self, img_stem: str, img_w: int, img_h: int) -> list:
        lbl_fp = self.val_lbl_dir / f"{img_stem}.txt"
        if not lbl_fp.exists():
            return []
        gts = []
        for line in lbl_fp.read_text().splitlines():
            parts = line.strip().split()
            if not parts:
                continue
            cls  = int(parts[0])
            pts  = list(map(float, parts[1:]))
            poly = [(pts[i] * img_w, pts[i + 1] * img_h) for i in range(0, len(pts) - 1, 2)]
            xs   = [p[0] for p in poly]
            ys   = [p[1] for p in poly]
            gts.append({"label": cls, "bbox": [min(xs), min(ys), max(xs), max(ys)], "poly": poly})
        return gts

    @staticmethod
    def _extract_preds(res) -> list:
        preds = []
        if res.boxes is None:
            return preds
        boxes   = res.boxes
        masks_r = res.masks
        for idx in range(len(boxes)):
            poly = (
                masks_r.xy[idx].tolist()
                if masks_r is not None and idx < len(masks_r.xy)
                else None
            )
            preds.append({
                "cls" : int(boxes.cls[idx]),
                "conf": float(boxes.conf[idx]),
                "bbox": boxes.xyxy[idx].cpu().numpy().tolist(),
                "poly": poly,
            })
        return preds

    @staticmethod
    def _iou_boxes(b1: list, b2: list) -> float:
        xi1 = max(b1[0], b2[0]); yi1 = max(b1[1], b2[1])
        xi2 = min(b1[2], b2[2]); yi2 = min(b1[3], b2[3])
        inter = max(0.0, xi2 - xi1) * max(0.0, yi2 - yi1)
        a1    = (b1[2] - b1[0]) * (b1[3] - b1[1])
        a2    = (b2[2] - b2[0]) * (b2[3] - b2[1])
        denom = a1 + a2 - inter
        return inter / denom if denom > 0 else 0.0

    @staticmethod
    def _iou_masks(m1: np.ndarray, m2: np.ndarray) -> float:
        inter = np.logical_and(m1, m2).sum()
        union = np.logical_or(m1,  m2).sum()
        return float(inter / union) if union > 0 else 0.0

    @staticmethod
    def _dice_masks(m1: np.ndarray, m2: np.ndarray) -> float:
        inter = np.logical_and(m1, m2).sum()
        denom = m1.sum() + m2.sum()
        return float(2 * inter / denom) if denom > 0 else 0.0

    @staticmethod
    def _compute_ap(preds_list: list, n_gt: int, iou_thresh: float = 0.5) -> float:
        if n_gt == 0 or not preds_list:
            return 0.0
        sorted_preds = sorted(preds_list, key=lambda x: x[0], reverse=True)
        tp     = np.array([1.0 if iou >= iou_thresh else 0.0 for _, iou in sorted_preds])
        cum_tp = np.cumsum(tp)
        cum_fp = np.cumsum(1.0 - tp)
        prec   = cum_tp / (cum_tp + cum_fp + 1e-9)
        rec    = cum_tp / (n_gt + 1e-9)
        return sum(
            (float(np.max(prec[rec >= r])) if (rec >= r).any() else 0.0) / 11.0
            for r in np.linspace(0.0, 1.0, 11)
        )

    @staticmethod
    def _prf_at_conf(
        preds_list: list, n_gt: int,
        conf_thresh: float = 0.25, iou_thresh: float = 0.50,
    ) -> tuple:
        filtered = [(c, iou) for c, iou in preds_list if c >= conf_thresh]
        tp = sum(1 for _, iou in filtered if iou >= iou_thresh)
        fp = len(filtered) - tp
        fn = max(0, n_gt - tp)
        P  = tp / (tp + fp + 1e-9)
        R  = tp / (tp + fn + 1e-9)
        F1 = 2.0 * P * R / (P + R + 1e-9)
        return P, R, F1


# ════════════════════════════════════════════════════════════
#  ENTRY POINT
# ════════════════════════════════════════════════════════════
def main() -> None:
    log = logging.getLogger(f"{ROOT_LOG.name}.main")

    log.info("Initialising DatasetConfig …")
    config = DatasetConfig()
    config.log_summary()

    log.info("Building YOLO dataset …")
    builder = YoloDataBuilder(config)
    n_train, n_val = builder.build_all()
    builder.compute_class_weights()

    yaml_path = config.generate_yaml()

    trainer = YoloTrainer(config)
    trainer.load_pretrained()
    best_model_path = trainer.train(yaml_path)

    evaluator = YoloEvaluator(config, best_model_path)
    evaluator.run_inference()
    evaluator.compute_detection_metrics()
    evaluator.compute_segmentation_metrics()
    evaluator.compute_roc_auc(config.results_dir)
    evaluator.plot_training_curves(trainer.save_dir)
    evaluator.plot_qualitative_predictions()
    evaluator.plot_per_class_bar_chart()
    evaluator.print_final_summary(n_train, n_val)

    log.info("ALL DONE.  Best model → %s", best_model_path)
    log.info("Outputs   → %s", config.results_dir)


if __name__ == "__main__":
    main()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.1 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 19:08:10  [INFO    ]  yolo_fashion.main — Initialising DatasetConfig …
# 19:08:10  [INFO    ]  yolo_fashion.config — GPU inventory: 2  ['Tesla T4', 'Tesla T4']
# 19:08:10  [INFO    ]  yolo_fashion.config — Devices — train: 0,1  infer: 0
# 19:08:10  [INFO    ]  yolo_fashion.config — Class mapping:
#  yolo_idx  df2_cat  sem_pixel             name
#         0        1          1 short_sleeve_top
#         1        8          2         trousers
#         2        7          3           shorts
#         3        2          4  long_sleeve_top
#         4        9          5            skirt
# 19:08:10  [INFO    ]  yolo_fashion.config — Hyperparameters:
#     parameter                                        value
#        epochs                                           15
#         imgsz                                          640
#         batch                                           32
#       workers                                            4
#        device                                          0,1
#      patience                                            5
#           lr0                                         0.01
#           lrf                                         0.01
#      momentum                                        0.937
#  weight_decay                                       0.0005
# warmup_epochs                                            3
#        cos_lr                                         True
#           amp                                         True
#         cache                                         disk
#       augment                                         True
#        mosaic                                          1.0
#         mixup                                          0.1
#    copy_paste                                          0.0
#       degrees                                         10.0
#     translate                                          0.1
#         scale                                          0.5
#        fliplr                                          0.5
#         hsv_h                                        0.015
#         hsv_s                                          0.7
#         hsv_v                                          0.4
#       verbose                                         True
#         plots                                         True
#          save                                         True
#       project /kaggle/working/yolo_fashion_scratch/results
#          name                         yolo_fashion_scratch
#      exist_ok                                         True
#    pretrained                                        False
#        freeze                                            0
# 19:08:10  [INFO    ]  yolo_fashion.main — Building YOLO dataset …
# 19:08:19  [INFO    ]  yolo_fashion.builder — [train] 144174 annotation files found in /kaggle/input/datasets/shubhranilbasak/vr-trimmed-dataset/Trimmed-vr-dataset/DeepFashion2_Top5_train/annos
#   Building [train]: 100%|██████████| 144174/144174 [16:13<00:00, 148.07it/s]
# 19:24:39  [INFO    ]  yolo_fashion.builder — [train] written=144174  skipped=0
# 19:24:40  [INFO    ]  yolo_fashion.builder — [validation] 23741 annotation files found in /kaggle/input/datasets/shubhranilbasak/vr-trimmed-dataset/Trimmed-vr-dataset/DeepFashion2_Top5_val/annos
#   Building [validation]: 100%|██████████| 23741/23741 [02:43<00:00, 145.22it/s]
# 19:27:24  [INFO    ]  yolo_fashion.builder — [validation] written=23741  skipped=0
# 19:27:24  [INFO    ]  yolo_fashion.builder — Dataset build complete.  train=144174  val=23741
# 19:27:53  [INFO    ]  yolo_fashion.builder — Class weights:
#  yolo_idx       class_name   count  weight
#         0 short_sleeve_top 71645.0  0.5841
#         1         trousers 55387.0  0.7555
#         2           shorts 36616.0  1.1429
#         3  long_sleeve_top 36064.0  1.1604
#         4            skirt 30835.0  1.3571
# 19:27:53  [INFO    ]  yolo_fashion.config — dataset.yaml → /kaggle/working/yolo_fashion_scratch/dataset/dataset.yaml
# 19:27:53  [INFO    ]  yolo_fashion.config — Classes (5): ['short_sleeve_top', 'trousers', 'shorts', 'long_sleeve_top', 'skirt']
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n-seg.pt to 'yolov8n-seg.pt': 100% ━━━━━━━━━━━━ 6.7MB 84.5MB/s 0.1s
# 19:27:54  [INFO    ]  yolo_fashion.trainer — Loaded yolov8n-seg.pt  (3,409,968 parameters)
# 19:27:54  [INFO    ]  yolo_fashion.trainer — Strategy: SCRATCH — all layers randomly initialised, nothing frozen
# 19:27:54  [INFO    ]  yolo_fashion.trainer — Epoch-timing callbacks registered.
# 19:27:54  [INFO    ]  yolo_fashion.trainer — Training configuration:
#     parameter                                        value
#        epochs                                           15
#         imgsz                                          640
#         batch                                           32
#       workers                                            4
#        device                                          0,1
#      patience                                            5
#           lr0                                         0.01
#           lrf                                         0.01
#      momentum                                        0.937
#  weight_decay                                       0.0005
# warmup_epochs                                            3
#        cos_lr                                         True
#           amp                                         True
#         cache                                         disk
#       augment                                         True
#        mosaic                                          1.0
#         mixup                                          0.1
#    copy_paste                                          0.0
#       degrees                                         10.0
#     translate                                          0.1
#         scale                                          0.5
#        fliplr                                          0.5
#         hsv_h                                        0.015
#         hsv_s                                          0.7
#         hsv_v                                          0.4
#       verbose                                         True
#         plots                                         True
#          save                                         True
#       project /kaggle/working/yolo_fashion_scratch/results
#          name                         yolo_fashion_scratch
#      exist_ok                                         True
#    pretrained                                        False
#        freeze                                            0
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/yolo_fashion_scratch/dataset/dataset.yaml, degrees=10.0, deterministic=True, device=0,1, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=15, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=0, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo_fashion_scratch, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=False, profile=False, project=/kaggle/working/yolo_fashion_scratch/results, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1005055  ultralytics.nn.modules.head.Segment          [5, 32, 64, 16, None, [64, 128, 256]]
# YOLOv8n-seg summary: 152 layers, 3,264,591 parameters, 3,264,575 gradients, 11.5 GFLOPs
#
# Transferred 381/417 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 50789 /root/.config/Ultralytics/DDP/_temp_1dp_6q56136471272385920.py
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# Overriding model.yaml nc=80 with nc=5
# Transferred 381/417 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 66.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 741.8±965.7 MB/s, size: 76.7 KB)
# train: Scanning /kaggle/working/yolo_fashion_scratch/dataset/labels/train... 144174 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 144174/144174 866.8it/s 2:46
# train: New cache created: /kaggle/working/yolo_fashion_scratch/dataset/labels/train.cache
# WARNING ⚠️ train: 315.2GB disk space required, with 50% safety margin but only 9.1/19.5GB free, not caching images to disk
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 977.7±224.1 MB/s, size: 55.3 KB)
# val: Scanning /kaggle/working/yolo_fashion_scratch/dataset/labels/validation... 23741 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 23741/23741 1.1Kit/s 21.6s
# val: New cache created: /kaggle/working/yolo_fashion_scratch/dataset/labels/validation.cache
# WARNING ⚠️ val: 47.7GB disk space required, with 50% safety margin but only 9.0/19.5GB free, not caching images to disk
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias(decay=0.0)
# Plotting labels to /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        1/15      2.71G     0.8987      2.255      1.709      1.203          0         35        640: 100% ━━━━━━━━━━━━ 4506/4506 1.8it/s 41:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.5it/s 2:31
#                    all      23741      38797      0.761      0.757      0.807      0.636      0.757      0.749      0.796      0.585
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        2/15      4.42G     0.8739      2.078       1.15      1.168          0         34        640: 100% ━━━━━━━━━━━━ 4506/4506 2.0it/s 38:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.4it/s 2:32
#                    all      23741      38797      0.798      0.813      0.848      0.691      0.794      0.806      0.839      0.642
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        3/15      4.42G      0.887      2.079      1.112      1.178          0         22        640: 100% ━━━━━━━━━━━━ 4506/4506 2.2it/s 34:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:21
#                    all      23741      38797      0.801      0.818      0.853      0.695      0.799       0.81      0.844      0.644
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        4/15      4.43G     0.8656      2.046      1.062      1.164          0         28        640: 100% ━━━━━━━━━━━━ 4506/4506 2.2it/s 34:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.5it/s 2:28
#                    all      23741      38797      0.818      0.832      0.867      0.719      0.814      0.827      0.858      0.663
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        5/15      4.43G     0.8171       1.95     0.9831      1.134          0         26        640: 100% ━━━━━━━━━━━━ 4506/4506 2.1it/s 35:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:25
#                    all      23741      38797      0.835      0.838      0.877      0.734      0.831      0.833      0.869      0.676
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        6/15      4.44G     0.7002      1.577     0.6788      1.078          0         12        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:24
#                    all      23741      38797      0.841      0.845      0.883      0.741      0.838       0.84      0.874      0.682
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        7/15      4.44G     0.6709      1.518     0.6336      1.057          0         12        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 30:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.5it/s 2:28
#                    all      23741      38797       0.84      0.852      0.886      0.746      0.836      0.847      0.878      0.686
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        8/15      4.44G     0.6465      1.475      0.603       1.04          0         10        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:10
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:25
#                    all      23741      38797      0.843      0.854      0.888       0.75      0.839      0.849       0.88      0.689
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        9/15      4.44G     0.6261      1.431     0.5713      1.027          0         11        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:24
#                    all      23741      38797      0.845      0.857       0.89      0.754       0.84      0.853      0.882      0.691
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       10/15      4.44G     0.6064      1.396      0.543      1.013          0         12        640: 100% ━━━━━━━━━━━━ 4506/4506 2.5it/s 30:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.8it/s 2:14
#                    all      23741      38797      0.851      0.858      0.892      0.758      0.847      0.854      0.884      0.694
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       11/15      4.44G     0.5882      1.354     0.5146     0.9994          0         12        640: 100% ━━━━━━━━━━━━ 4506/4506 2.5it/s 30:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:23
#                    all      23741      38797      0.852      0.861      0.895      0.762      0.848      0.856      0.887      0.697
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       12/15      4.44G     0.5698      1.322     0.4929     0.9885          0         10        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:25
#                    all      23741      38797      0.854      0.864      0.897      0.765       0.85      0.859      0.889        0.7
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       13/15      4.44G     0.5556      1.292     0.4701       0.98          0         10        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:23
#                    all      23741      38797      0.857      0.865        0.9      0.769      0.853      0.859      0.892      0.702
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       14/15      4.44G     0.5423      1.267      0.454     0.9716          0         12        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:24
#                    all      23741      38797      0.859      0.866      0.902      0.772      0.856      0.861      0.894      0.705
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       15/15      4.44G      0.535      1.256     0.4451     0.9672          0         11        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.7it/s 2:18
#                    all      23741      38797       0.86      0.868      0.904      0.775      0.858      0.862      0.896      0.706
#
# 15 epochs completed in 8.846 hours.
# Optimizer stripped from /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch/weights/last.pt, 6.8MB
# Optimizer stripped from /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch/weights/best.pt, 6.8MB
#
# Validating /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch/weights/best.pt...
# YOLOv8n-seg summary (fused): 86 layers, 3,259,039 parameters, 0 gradients, 11.3 GFLOPs
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 0% ──────────── 1/371 1.1s/it 0.3s<6:47WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 1% ──────────── 2/371 1.0s/it 1.2s<6:12WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 1% ──────────── 3/371 1.1it/s 2.0s<5:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 1% ──────────── 4/371 1.2it/s 2.7s<5:19WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 1% ──────────── 5/371 1.5it/s 3.2s<4:08WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 2% ──────────── 6/371 2.0it/s 3.5s<3:03WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 2% ──────────── 7/371 2.3it/s 3.8s<2:41WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 2% ──────────── 8/371 2.6it/s 4.1s<2:22WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 2% ──────────── 9/371 2.7it/s 4.5s<2:13WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 3% ──────────── 10/371 2.8it/s 4.8s<2:07WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 3% ──────────── 11/371 2.9it/s 5.1s<2:03WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 3% ──────────── 12/371 3.0it/s 5.4s<1:60WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 4% ──────────── 13/371 3.1it/s 5.7s<1:57WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 4% ──────────── 14/371 3.1it/s 6.0s<1:56WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 4% ──────────── 15/371 3.1it/s 6.4s<1:56WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 4% ╸─────────── 16/371 3.0it/s 6.7s<1:58WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 5% ╸─────────── 17/371 3.0it/s 7.0s<1:57WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 5% ╸─────────── 18/371 3.0it/s 7.4s<1:57WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 5% ╸─────────── 19/371 3.0it/s 7.7s<1:56WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 5% ╸─────────── 20/371 3.1it/s 8.0s<1:55WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 6% ╸─────────── 21/371 3.1it/s 8.3s<1:54WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 6% ╸─────────── 22/371 3.1it/s 8.7s<1:53WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 6% ╸─────────── 23/371 3.1it/s 9.0s<1:53WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 6% ╸─────────── 24/371 3.1it/s 9.3s<1:52WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 7% ╸─────────── 25/371 3.1it/s 9.6s<1:52WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 7% ╸─────────── 26/371 3.1it/s 10.0s<1:51WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 7% ╸─────────── 27/371 3.1it/s 10.3s<1:51WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 8% ╸─────────── 28/371 3.1it/s 10.6s<1:50WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 8% ╸─────────── 29/371 3.1it/s 10.9s<1:51WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 8% ╸─────────── 30/371 3.1it/s 11.2s<1:50WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 8% ━─────────── 31/371 3.1it/s 11.6s<1:50WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 9% ━─────────── 32/371 3.1it/s 11.9s<1:49WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 9% ━─────────── 33/371 3.1it/s 12.2s<1:49WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 9% ━─────────── 34/371 3.1it/s 12.5s<1:49WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 9% ━─────────── 35/371 3.0it/s 12.9s<1:52WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 10% ━─────────── 36/371 3.0it/s 13.2s<1:52WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 10% ━─────────── 37/371 2.9it/s 13.6s<1:55WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 10% ━─────────── 38/371 2.9it/s 13.9s<1:53WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 11% ━─────────── 39/371 2.6it/s 14.5s<2:06WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 11% ━─────────── 40/371 2.7it/s 14.8s<2:01WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 11% ━─────────── 41/371 2.8it/s 15.1s<1:58WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 11% ━─────────── 42/371 2.9it/s 15.5s<1:55WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 12% ━─────────── 43/371 2.9it/s 15.8s<1:52WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 12% ━─────────── 44/371 3.0it/s 16.1s<1:51WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 12% ━─────────── 45/371 2.9it/s 16.5s<1:53WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 12% ━─────────── 46/371 2.9it/s 16.8s<1:52WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 13% ━╸────────── 47/371 3.0it/s 17.1s<1:49WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 13% ━╸────────── 48/371 3.0it/s 17.5s<1:48WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 13% ━╸────────── 49/371 3.0it/s 17.8s<1:47WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 13% ━╸────────── 50/371 3.0it/s 18.1s<1:47WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 14% ━╸────────── 51/371 3.0it/s 18.5s<1:45WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 14% ━╸────────── 52/371 3.1it/s 18.8s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 14% ━╸────────── 53/371 3.1it/s 19.1s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 15% ━╸────────── 54/371 3.1it/s 19.4s<1:42WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 15% ━╸────────── 55/371 3.1it/s 19.7s<1:41WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 15% ━╸────────── 56/371 3.1it/s 20.0s<1:40WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 15% ━╸────────── 57/371 3.1it/s 20.4s<1:41WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 16% ━╸────────── 58/371 3.1it/s 20.7s<1:42WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 16% ━╸────────── 59/371 3.0it/s 21.0s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 16% ━╸────────── 60/371 3.0it/s 21.4s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 16% ━╸────────── 61/371 3.0it/s 21.7s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 17% ━━────────── 62/371 3.0it/s 22.1s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 17% ━━────────── 63/371 2.9it/s 22.4s<1:45WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 17% ━━────────── 64/371 3.0it/s 22.7s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 18% ━━────────── 65/371 2.9it/s 23.1s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 18% ━━────────── 66/371 2.9it/s 23.4s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 18% ━━────────── 67/371 3.0it/s 23.8s<1:42WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 18% ━━────────── 68/371 3.0it/s 24.1s<1:42WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 19% ━━────────── 69/371 2.9it/s 24.5s<1:45WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 19% ━━────────── 70/371 2.9it/s 24.8s<1:45WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 19% ━━────────── 71/371 2.9it/s 25.2s<1:45WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 19% ━━────────── 72/371 2.9it/s 25.5s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 20% ━━────────── 73/371 2.9it/s 25.8s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 20% ━━────────── 74/371 2.9it/s 26.2s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 20% ━━────────── 75/371 2.8it/s 26.6s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 20% ━━────────── 76/371 2.8it/s 26.9s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 21% ━━────────── 77/371 2.8it/s 27.3s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 21% ━━╸───────── 78/371 2.9it/s 27.6s<1:42WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 21% ━━╸───────── 79/371 2.9it/s 28.0s<1:41WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 22% ━━╸───────── 80/371 2.8it/s 28.3s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 22% ━━╸───────── 81/371 2.7it/s 28.7s<1:46WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 22% ━━╸───────── 82/371 2.7it/s 29.1s<1:46WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 22% ━━╸───────── 83/371 2.7it/s 29.5s<1:45WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 23% ━━╸───────── 84/371 2.8it/s 29.8s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 23% ━━╸───────── 85/371 2.8it/s 30.2s<1:42WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 23% ━━╸───────── 86/371 2.8it/s 30.5s<1:43WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 23% ━━╸───────── 87/371 2.7it/s 30.9s<1:44WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 24% ━━╸───────── 88/371 2.8it/s 31.2s<1:42WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 24% ━━╸───────── 89/371 2.8it/s 31.6s<1:41WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 24% ━━╸───────── 90/371 2.8it/s 31.9s<1:39WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 25% ━━╸───────── 91/371 2.8it/s 32.3s<1:39WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 25% ━━╸───────── 92/371 2.8it/s 32.7s<1:40WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 25% ━━━───────── 93/371 2.8it/s 33.0s<1:40WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 96% ━━━━━━━━━━━╸ 358/371 2.6it/s 2:06<5.0sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 97% ━━━━━━━━━━━╸ 359/371 2.7it/s 2:07<4.5sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 97% ━━━━━━━━━━━╸ 360/371 2.8it/s 2:07<3.9sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 97% ━━━━━━━━━━━╸ 361/371 3.0it/s 2:07<3.3sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 98% ━━━━━━━━━━━╸ 362/371 3.1it/s 2:08<2.9sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 98% ━━━━━━━━━━━╸ 363/371 3.2it/s 2:08<2.5sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 98% ━━━━━━━━━━━╸ 364/371 3.2it/s 2:08<2.2sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 98% ━━━━━━━━━━━╸ 365/371 3.2it/s 2:09<1.9sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 99% ━━━━━━━━━━━╸ 366/371 3.2it/s 2:09<1.6sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 99% ━━━━━━━━━━━╸ 367/371 3.2it/s 2:09<1.3sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 99% ━━━━━━━━━━━╸ 368/371 3.4it/s 2:10<0.9sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 99% ━━━━━━━━━━━╸ 369/371 3.4it/s 2:10<0.6sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━╸ 370/371 3.4it/s 2:10<0.3sWARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.8it/s 2:10
#                    all      23741      38797      0.861      0.868      0.904      0.775      0.858      0.862      0.896      0.706
#       short_sleeve_top      12371      12556      0.898      0.913      0.961      0.887      0.899      0.911      0.959      0.813
#               trousers       9494       9586       0.87      0.895      0.891      0.729      0.857       0.88      0.873       0.65
#                 shorts       4133       4167       0.87      0.838      0.912      0.731      0.872      0.835      0.909      0.696
#        long_sleeve_top       5916       5966      0.793      0.806      0.825      0.722      0.794      0.803      0.823      0.611
#                  skirt       6499       6522      0.873      0.889       0.93      0.805      0.867       0.88      0.914      0.762
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch
# 04:24:54  [INFO    ]  yolo_fashion.trainer — Training finished in 32220.3s  (537m 0s)
# 04:24:54  [INFO    ]  yolo_fashion.trainer — Save dir   : /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch
# 04:24:54  [INFO    ]  yolo_fashion.trainer — Best model : /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch/weights/best.pt
# 04:24:54  [INFO    ]  yolo_fashion.trainer — Epoch-by-epoch training log:
#  epoch     time  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  train/sem_loss  metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  metrics/mAP50-95(B)  metrics/precision(M)  metrics/recall(M)  metrics/mAP50(M)  metrics/mAP50-95(M)  val/box_loss  val/seg_loss  val/cls_loss  val/dfl_loss  val/sem_loss  lr/pg0  lr/pg1  lr/pg2  lr/pg3  lr/pg4  lr/pg5  lr/pg6  lr/pg7
#      1  2650.68          0.8987          2.2547          1.7090          1.2031               0                0.7614             0.7566            0.8068               0.6357                0.7571             0.7490            0.7962               0.5848        0.7375        1.5985        0.8548        1.0623             0  0.0100  0.0033  0.0100  0.0033  0.0100  0.0033  0.0100  0.0033
#      2  5107.19          0.8739          2.0782          1.1504          1.1685               0                0.7977             0.8132            0.8477               0.6911                0.7944             0.8061            0.8394               0.6421        0.6797        1.4617        0.6822        1.0259             0  0.0198  0.0066  0.0198  0.0066  0.0198  0.0066  0.0198  0.0066
#      3  7314.10          0.8870          2.0786          1.1124          1.1784               0                0.8010             0.8176            0.8528               0.6951                0.7988             0.8101            0.8438               0.6437        0.6787        1.4693        0.6569        1.0275             0  0.0287  0.0096  0.0287  0.0096  0.0287  0.0096  0.0287  0.0096
#      4  9511.23          0.8656          2.0461          1.0619          1.1642               0                0.8180             0.8317            0.8671               0.7190                0.8136             0.8272            0.8584               0.6627        0.6472        1.4184        0.6102        0.9994             0  0.0272  0.0091  0.0272  0.0091  0.0272  0.0091  0.0272  0.0091
#      5 11764.70          0.8171          1.9499          0.9831          1.1335               0                0.8349             0.8384            0.8771               0.7337                0.8314             0.8327            0.8690               0.6763        0.6274        1.3848        0.5748        0.9831             0  0.0251  0.0084  0.0251  0.0084  0.0251  0.0084  0.0251  0.0084
#      6 13790.50          0.7002          1.5765          0.6788          1.0784               0                0.8411             0.8451            0.8827               0.7410                0.8376             0.8396            0.8745               0.6824        0.6201        1.3726        0.5555        0.9744             0  0.0226  0.0075  0.0226  0.0075  0.0226  0.0075  0.0226  0.0075
#      7 15779.50          0.6709          1.5182          0.6336          1.0568               0                0.8404             0.8518            0.8857               0.7462                0.8362             0.8469            0.8776               0.6858        0.6146        1.3651        0.5448        0.9687             0  0.0197  0.0066  0.0197  0.0066  0.0197  0.0066  0.0197  0.0066
#      8 17795.70          0.6465          1.4753          0.6030          1.0399               0                0.8430             0.8535            0.8878               0.7504                0.8386             0.8491            0.8798               0.6889        0.6095        1.3584        0.5367        0.9640             0  0.0167  0.0056  0.0167  0.0056  0.0167  0.0056  0.0167  0.0056
#      9 19842.40          0.6261          1.4311          0.5713          1.0268               0                0.8446             0.8574            0.8897               0.7537                0.8403             0.8527            0.8818               0.6912        0.6051        1.3520        0.5291        0.9599             0  0.0136  0.0045  0.0136  0.0045  0.0136  0.0045  0.0136  0.0045
#     10 21803.00          0.6064          1.3958          0.5430          1.0133               0                0.8510             0.8584            0.8924               0.7578                0.8466             0.8539            0.8843               0.6941        0.6009        1.3468        0.5210        0.9559             0  0.0106  0.0035  0.0106  0.0035  0.0106  0.0035  0.0106  0.0035
#     11 23747.40          0.5882          1.3535          0.5146          0.9994               0                0.8525             0.8611            0.8948               0.7615                0.8482             0.8562            0.8867               0.6968        0.5960        1.3409        0.5137        0.9513             0  0.0077  0.0026  0.0077  0.0026  0.0077  0.0026  0.0077  0.0026
#     12 25781.10          0.5698          1.3224          0.4929          0.9885               0                0.8544             0.8637            0.8974               0.7653                0.8504             0.8586            0.8893               0.6997        0.5921        1.3358        0.5070        0.9477             0  0.0052  0.0017  0.0052  0.0017  0.0052  0.0017  0.0052  0.0017
#     13 27829.30          0.5556          1.2921          0.4701          0.9800               0                0.8574             0.8648            0.8998               0.7689                0.8532             0.8594            0.8918               0.7022        0.5883        1.3311        0.5008        0.9442             0  0.0031  0.0010  0.0031  0.0010  0.0031  0.0010  0.0031  0.0010
#     14 29846.20          0.5423          1.2668          0.4540          0.9716               0                0.8594             0.8662            0.9022               0.7721                0.8556             0.8606            0.8940               0.7046        0.5850        1.3271        0.4955        0.9411             0  0.0016  0.0005  0.0016  0.0005  0.0016  0.0005  0.0016  0.0005
#     15 31846.70          0.5350          1.2561          0.4451          0.9672               0                0.8604             0.8683            0.9038               0.7747                0.8580             0.8618            0.8956               0.7063        0.5819        1.3242        0.4910        0.9383             0  0.0006  0.0002  0.0006  0.0002  0.0006  0.0002  0.0006  0.0002
# 04:24:54  [INFO    ]  yolo_fashion.evaluator — Best model loaded from /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch/weights/best.pt
# 04:24:55  [INFO    ]  yolo_fashion.evaluator — Validation images available: 23741
# 04:24:55  [INFO    ]  yolo_fashion.evaluator — Batched GPU inference — 23741 images, batch_size=16, device=0
# GPU inference: 100%|██████████| 1484/1484 [09:44<00:00,  2.54it/s]
# 04:34:39  [INFO    ]  yolo_fashion.evaluator — Inference and metric accumulation complete.
# 04:34:40  [INFO    ]  yolo_fashion.evaluator — Detection metrics:
#            class  AP@0.50  AP@0.75  mAP@[.5:.95]  Precision  Recall     F1
# short_sleeve_top   0.8921   0.8866        0.8255     0.8668  0.9540 0.9083
#         trousers   0.8505   0.7596        0.6887     0.8385  0.9199 0.8773
#           shorts   0.7964   0.7880        0.6486     0.8269  0.8608 0.8435
#  long_sleeve_top   0.7367   0.7205        0.6538     0.7621  0.8419 0.8000
#            skirt   0.8672   0.8593        0.7515     0.8467  0.9112 0.8778
#    Macro Average   0.8286   0.8028        0.7136     0.8282  0.8976 0.8614
# 04:34:40  [INFO    ]  yolo_fashion.evaluator — Segmentation metrics (background pixel=0 excluded):
#            class sem_pixel   mIoU   Dice n_images
# short_sleeve_top         1 0.8124 0.8688    12371
#         trousers         2 0.7120 0.7947     9494
#           shorts         3 0.6588 0.7274     4131
#  long_sleeve_top         4 0.6819 0.7402     5915
#            skirt         5 0.7610 0.8088     6499
#    Macro Average         — 0.7252 0.7880        —
# 04:34:41  [INFO    ]  yolo_fashion.evaluator — ROC AUC:
#            class    AUC
# short_sleeve_top 0.9656
#         trousers 0.9750
#           shorts 0.9344
#  long_sleeve_top 0.9380
#            skirt 0.9555
#    Macro Average 0.9537
# 04:34:41  [INFO    ]  yolo_fashion.evaluator — ROC figure saved → /kaggle/working/yolo_fashion_scratch/results/roc_curves_detection.png
# 04:34:45  [INFO    ]  yolo_fashion.evaluator — Training curves saved → /kaggle/working/yolo_fashion_scratch/results/training_curves.png
# /tmp/ipykernel_23/598084346.py:659: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", self.cfg.num_classes)
# 04:34:47  [INFO    ]  yolo_fashion.evaluator — Qualitative visualisation saved → /kaggle/working/yolo_fashion_scratch/results/qualitative_predictions.png
# 04:34:48  [INFO    ]  yolo_fashion.evaluator — Per-class bar chart saved → /kaggle/working/yolo_fashion_scratch/results/per_class_metrics.png
# 04:34:48  [INFO    ]  yolo_fashion.evaluator — === FINAL METRICS SUMMARY ===
# 04:34:48  [INFO    ]  yolo_fashion.evaluator — GPU(s): 2× Tesla T4  |  train=144174  val=23741  epochs=15  imgsz=640  batch=32
# 04:34:48  [INFO    ]  yolo_fashion.evaluator — Full per-class summary:
#            class  AP@0.50  AP@0.75  mAP@[.5:.95]  Precision  Recall     F1   mIoU   Dice    AUC
# short_sleeve_top   0.8921   0.8866        0.8255     0.8668  0.9540 0.9083 0.8124 0.8688 0.9656
#         trousers   0.8505   0.7596        0.6887     0.8385  0.9199 0.8773 0.7120 0.7947 0.9750
#           shorts   0.7964   0.7880        0.6486     0.8269  0.8608 0.8435 0.6588 0.7274 0.9344
#  long_sleeve_top   0.7367   0.7205        0.6538     0.7621  0.8419 0.8000 0.6819 0.7402 0.9380
#            skirt   0.8672   0.8593        0.7515     0.8467  0.9112 0.8778 0.7610 0.8088 0.9555
#    Macro Average   0.8286   0.8028        0.7136     0.8282  0.8976 0.8614 0.7252 0.7880 0.9537
# 04:34:48  [INFO    ]  yolo_fashion.evaluator — Semantic mask pixel legend:
# 04:34:48  [INFO    ]  yolo_fashion.evaluator —   pixel 0 = background (unannotated)
# 04:34:48  [INFO    ]  yolo_fashion.evaluator —   pixel 1 = short_sleeve_top  (YOLO class 0)
# 04:34:48  [INFO    ]  yolo_fashion.evaluator —   pixel 2 = trousers  (YOLO class 1)
# 04:34:48  [INFO    ]  yolo_fashion.evaluator —   pixel 3 = shorts  (YOLO class 2)
# 04:34:48  [INFO    ]  yolo_fashion.evaluator —   pixel 4 = long_sleeve_top  (YOLO class 3)
# 04:34:48  [INFO    ]  yolo_fashion.evaluator —   pixel 5 = skirt  (YOLO class 4)
# 04:34:48  [INFO    ]  yolo_fashion.evaluator — Outputs saved to: /kaggle/working/yolo_fashion_scratch/results
# 04:34:48  [INFO    ]  yolo_fashion.main — ALL DONE.  Best model → /kaggle/working/yolo_fashion_scratch/results/yolo_fashion_scratch/weights/best.pt
# 04:34:48  [INFO    ]  yolo_fashion.main — Outputs   → /kaggle/working/yolo_fashion_scratch/results
