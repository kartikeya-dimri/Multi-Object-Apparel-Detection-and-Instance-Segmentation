# %%
# ============================================================
#  YOLO Fine-Tuning — DeepFashion2 Top-5 Categories
#  Native DF2 Dataset  |  Dual-GPU (T4×2)
#  Task 3.2: Detection + Segmentation
# ============================================================

# ─── 0. INSTALLATION ────────────────────────────────────────
import subprocess, sys

def _install(pkg: str) -> None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])

for _pkg in [
    "ultralytics", "scikit-learn", "matplotlib", "seaborn",
    "Pillow", "tqdm", "pyyaml", "opencv-python-headless", "pandas",
]:
    _install(_pkg)

# ─── 1. STDLIB / THIRD-PARTY IMPORTS ────────────────────────
import json
import logging
import multiprocessing as mp
import random
import shutil
import time
import warnings
from collections import defaultdict
from concurrent.futures import ProcessPoolExecutor, as_completed
from pathlib import Path

import cv2
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import yaml
from PIL import Image
from sklearn.metrics import auc, roc_curve
from tqdm import tqdm
from ultralytics import YOLO

warnings.filterwarnings("ignore", category=FutureWarning)

# ─── 2. LOGGING SETUP ───────────────────────────────────────
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s  [%(levelname)-8s]  %(name)s — %(message)s",
    datefmt="%H:%M:%S",
)
ROOT_LOG = logging.getLogger("yolo_fashion")


# ════════════════════════════════════════════════════════════
#  CLASS 1 — DatasetConfig
# ════════════════════════════════════════════════════════════
class DatasetConfig:
    """
    Class mapping contract
    ─────────────────────
    DF2 cat_id  →  YOLO idx  →  class name
    ─────────────────────────────────────────
         1      →     0     →  short_sleeve_top
         8      →     1     →  trousers
         7      →     2     →  shorts
         2      →     3     →  long_sleeve_top
         9      →     4     →  skirt

    Semantic mask convention:
        pixel 0  = background
        pixel N  = foreground (N = yolo_idx + 1)

    Fine-tuning strategy
    ─────────────────────
    • pretrained=True   → start from COCO weights
    • freeze=10         → first 10 backbone layers frozen
    • lr0=1e-5          → small LR to preserve pretrained features
    • warmup_epochs=1   → short warmup since weights already good
    """

    _DF2_REGISTRY: dict = {
        1: "short_sleeve_top",  2: "long_sleeve_top",
        3: "short_sleeve_outwear", 4: "long_sleeve_outwear",
        5: "vest",              6: "sling",
        7: "shorts",            8: "trousers",
        9: "skirt",            10: "short_sleeve_dress",
        11: "long_sleeve_dress", 12: "vest_dress",
        13: "sling_dress",
    }

    def __init__(self) -> None:
        self._log = logging.getLogger(f"{ROOT_LOG.name}.config")

        # ── Paths ────────────────────────────────────────────
        _base = Path(
            "/kaggle/input/datasets/shubhranilbasak"
            "/vr-trimmed-dataset/Trimmed-vr-dataset"
        )

        self.annos_base: dict = {
            "train"      : _base / "DeepFashion2_Top5_train" / "annos",
            "validation" : _base / "DeepFashion2_Top5_val"   / "annos",
        }
        self.img_base: dict = {
            "train"      : _base / "DeepFashion2_Top5_train" / "images",
            "validation" : _base / "DeepFashion2_Top5_val"   / "images",
        }

        self.work_dir    = Path("/kaggle/working/yolo_fashion_finetune")
        self.dataset_dir = self.work_dir / "dataset"
        self.results_dir = self.work_dir / "results"
        for _d in [self.work_dir, self.dataset_dir, self.results_dir]:
            _d.mkdir(parents=True, exist_ok=True)

        # ── Class Mapping ────────────────────────────────────
        self.top5_cat_ids: list = [1, 8, 7, 2, 9]
        self.cat_id_to_yolo: dict = {
            cat_id: yolo_idx
            for yolo_idx, cat_id in enumerate(self.top5_cat_ids)
        }
        self.yolo_to_name: dict = {
            yolo_idx: self._DF2_REGISTRY[cat_id]
            for yolo_idx, cat_id in enumerate(self.top5_cat_ids)
        }
        self.num_classes: int = len(self.top5_cat_ids)

        # ── GPU Setup ────────────────────────────────────────
        self.num_gpus   = torch.cuda.device_count()
        self.gpu_names  = [torch.cuda.get_device_name(i) for i in range(self.num_gpus)]
        self.device_str = (
            ",".join(str(i) for i in range(self.num_gpus))
            if self.num_gpus > 0 else "cpu"
        )
        self.infer_device  = "0" if self.num_gpus > 0 else "cpu"
        self.num_workers   = min(8, mp.cpu_count())
        self.prep_workers  = max(1, mp.cpu_count() - 1)

        # ── Model ────────────────────────────────────────────
        self.base_weights   = "yolov8n-seg.pt"
        self.infer_batch_sz = 16

        # ── Training Hyperparameters ─────────────────────────
        # Fine-tuning key settings:
        #   pretrained=True  → load COCO weights
        #   freeze=10        → freeze first 10 backbone layers
        #   lr0=1e-5         → small LR to avoid overwriting pretrained features
        #   warmup_epochs=1  → short warmup
        self.train_hp: dict = {
            "epochs"        : 15,
            "imgsz"         : 640,
            "batch"         : 32,
            "workers"       : self.num_workers,
            "device"        : self.device_str,
            "patience"      : 5,
            "lr0"           : 1e-5,       # ← fine-tuning LR
            "lrf"           : 0.01,
            "momentum"      : 0.937,
            "weight_decay"  : 0.0005,
            "warmup_epochs" : 1,          # ← short warmup
            "cos_lr"        : True,
            "amp"           : True,
            "cache"         : "disk",
            "augment"       : True,
            "mosaic"        : 1.0,
            "mixup"         : 0.1,
            "copy_paste"    : 0.0,
            "degrees"       : 10.0,
            "translate"     : 0.1,
            "scale"         : 0.5,
            "fliplr"        : 0.5,
            "hsv_h"         : 0.015,
            "hsv_s"         : 0.7,
            "hsv_v"         : 0.4,
            "verbose"       : True,
            "plots"         : True,
            "save"          : True,
            "project"       : str(self.results_dir),
            "name"          : "yolo_fashion_finetune",
            "exist_ok"      : True,
            "pretrained"    : True,       # ← COCO pretrained weights
            "freeze"        : 10,         # ← freeze first 10 backbone layers
        }
        self.yaml_path: Path = self.dataset_dir / "dataset.yaml"

    def generate_yaml(self) -> Path:
        cfg = {
            "path"  : str(self.dataset_dir),
            "train" : "images/train",
            "val"   : "images/validation",
            "nc"    : self.num_classes,
            "names" : [self.yolo_to_name[i] for i in range(self.num_classes)],
        }
        with open(self.yaml_path, "w") as fh:
            yaml.dump(cfg, fh, default_flow_style=False)
        self._log.info("dataset.yaml → %s", self.yaml_path)
        self._log.info("Classes (%d): %s", self.num_classes, cfg["names"])
        return self.yaml_path

    def log_summary(self) -> None:
        self._log.info("GPU inventory: %d  %s", self.num_gpus, self.gpu_names)
        self._log.info("Devices — train: %s  infer: %s", self.device_str, self.infer_device)
        class_df = pd.DataFrame([
            {"yolo_idx": yi, "df2_cat": self.top5_cat_ids[yi],
             "sem_pixel": yi + 1, "name": self.yolo_to_name[yi]}
            for yi in range(self.num_classes)
        ])
        self._log.info("Class mapping:\n%s", class_df.to_string(index=False))
        hp_df = pd.DataFrame(list(self.train_hp.items()), columns=["parameter", "value"])
        self._log.info("Hyperparameters:\n%s", hp_df.to_string(index=False))


# ════════════════════════════════════════════════════════════
#  MODULE-LEVEL WORKER
# ════════════════════════════════════════════════════════════
def _convert_record(args: tuple) -> bool:
    anno_fp_str, img_dir_str, cat_id_to_yolo, img_out_str, lbl_out_str, mask_out_str = args

    anno_fp  = Path(anno_fp_str)
    img_dir  = Path(img_dir_str)
    img_out  = Path(img_out_str)
    lbl_out  = Path(lbl_out_str)
    mask_out = Path(mask_out_str)

    stem   = anno_fp.stem
    img_fp = img_dir / f"{stem}.jpg"
    if not img_fp.exists():
        img_fp = img_dir / f"{stem}.png"
    if not img_fp.exists():
        return False

    try:
        with open(anno_fp) as fh:
            anno = json.load(fh)
    except Exception:
        return False

    valid_items = []
    for key, item in anno.items():
        if not key.startswith("item"):
            continue
        cat_id = item.get("category_id", -1)
        if cat_id not in cat_id_to_yolo:
            continue
        segs     = item.get("segmentation", [[]])
        raw_poly = segs[0] if segs else []
        valid_items.append({
            "yolo_cls": cat_id_to_yolo[cat_id],
            "polygon" : raw_poly,
        })

    if not valid_items:
        return False

    try:
        pil_img      = Image.open(img_fp)
        img_w, img_h = pil_img.size
    except Exception:
        return False

    sem_mask    = np.zeros((img_h, img_w), dtype=np.uint8)
    label_lines = []

    for item in valid_items:
        yolo_cls = item["yolo_cls"]
        sem_idx  = yolo_cls + 1
        raw_poly = item["polygon"]

        if len(raw_poly) < 6:
            continue

        pts_abs = [
            [int(round(raw_poly[i])), int(round(raw_poly[i + 1]))]
            for i in range(0, len(raw_poly) - 1, 2)
        ]
        pts_np = np.array(pts_abs, dtype=np.int32).reshape((-1, 1, 2))
        pts_np[..., 0] = np.clip(pts_np[..., 0], 0, img_w - 1)
        pts_np[..., 1] = np.clip(pts_np[..., 1], 0, img_h - 1)
        cv2.fillPoly(sem_mask, [pts_np], int(sem_idx))

        norm_coords = []
        for i in range(0, len(raw_poly) - 1, 2):
            norm_coords.append(max(0.0, min(1.0, raw_poly[i]     / img_w)))
            norm_coords.append(max(0.0, min(1.0, raw_poly[i + 1] / img_h)))

        pts_str = " ".join(f"{v:.6f}" for v in norm_coords)
        label_lines.append(f"{yolo_cls} {pts_str}")

    if not label_lines:
        return False

    (lbl_out  / f"{stem}.txt").write_text("\n".join(label_lines))
    Image.fromarray(sem_mask).save(mask_out / f"{stem}.png")

    dst = img_out / img_fp.name
    if not dst.exists():
        shutil.copy2(img_fp, dst)

    return True


# ════════════════════════════════════════════════════════════
#  CLASS 2 — YoloDataBuilder
# ════════════════════════════════════════════════════════════
class YoloDataBuilder:

    def __init__(self, config: DatasetConfig) -> None:
        self.cfg  = config
        self._log = logging.getLogger(f"{ROOT_LOG.name}.builder")

    def build_all(self) -> tuple:
        n_train = self._build_split("train")
        n_val   = self._build_split("validation")
        self._log.info("Dataset build complete.  train=%d  val=%d", n_train, n_val)
        return n_train, n_val

    def compute_class_weights(self) -> np.ndarray:
        lbl_dir = self.cfg.dataset_dir / "labels" / "train"
        counts  = np.zeros(self.cfg.num_classes, dtype=np.float64)
        for fp in lbl_dir.glob("*.txt"):
            for line in fp.read_text().splitlines():
                parts = line.strip().split()
                if parts:
                    counts[int(parts[0])] += 1
        counts  = np.where(counts == 0, 1.0, counts)
        weights = 1.0 / counts
        weights = weights / weights.sum() * self.cfg.num_classes
        df = pd.DataFrame({
            "yolo_idx"  : range(self.cfg.num_classes),
            "class_name": [self.cfg.yolo_to_name[i] for i in range(self.cfg.num_classes)],
            "count"     : counts,
            "weight"    : weights,
        })
        self._log.info("Class weights:\n%s", df.round(4).to_string(index=False))
        return weights

    def _build_split(self, split_name: str) -> int:
        img_out  = self.cfg.dataset_dir / "images"    / split_name
        lbl_out  = self.cfg.dataset_dir / "labels"    / split_name
        mask_out = self.cfg.dataset_dir / "seg_masks" / split_name
        for _d in [img_out, lbl_out, mask_out]:
            _d.mkdir(parents=True, exist_ok=True)

        annos_dir  = self.cfg.annos_base[split_name]
        anno_files = sorted(annos_dir.glob("*.json"))
        img_dir    = self.cfg.img_base[split_name]

        self._log.info(
            "[%s] %d annotation files found in %s",
            split_name, len(anno_files), annos_dir,
        )

        worker_args = [
            (str(af), str(img_dir), self.cfg.cat_id_to_yolo,
             str(img_out), str(lbl_out), str(mask_out))
            for af in anno_files
        ]

        written = skipped = 0
        with ProcessPoolExecutor(max_workers=self.cfg.prep_workers) as executor:
            future_map = {
                executor.submit(_convert_record, arg): arg
                for arg in worker_args
            }
            with tqdm(total=len(future_map), desc=f"  Building [{split_name}]") as pbar:
                for future in as_completed(future_map):
                    if future.result():
                        written += 1
                    else:
                        skipped += 1
                    pbar.update(1)

        self._log.info("[%s] written=%d  skipped=%d", split_name, written, skipped)
        return written


# ════════════════════════════════════════════════════════════
#  CLASS 3 — YoloTrainer
# ════════════════════════════════════════════════════════════
class YoloTrainer:

    def __init__(self, config: DatasetConfig) -> None:
        self.cfg      = config
        self._log     = logging.getLogger(f"{ROOT_LOG.name}.trainer")
        self.model    = None
        self.save_dir: Path = None

    def load_pretrained(self) -> YOLO:
        self.model = YOLO(self.cfg.base_weights)

        self._epoch_times: list  = []
        self._epoch_start: float = 0.0

        self.model.add_callback("on_train_epoch_start", self._cb_epoch_start)
        self.model.add_callback("on_train_epoch_end",   self._cb_epoch_end)

        n_params = sum(p.numel() for p in self.model.model.parameters())
        self._log.info("Loaded %s  (%s parameters)", self.cfg.base_weights, f"{n_params:,}")
        self._log.info(
            "Strategy: FINE-TUNING — COCO pretrained, %d backbone layers frozen, lr=%.0e",
            self.cfg.train_hp["freeze"], self.cfg.train_hp["lr0"],
        )
        self._log.info("Epoch-timing callbacks registered.")
        return self.model

    def train(self, yaml_path: Path) -> Path:
        hp    = self.cfg.train_hp
        hp_df = pd.DataFrame(list(hp.items()), columns=["parameter", "value"])
        self._log.info("Training configuration:\n%s", hp_df.to_string(index=False))

        t_start   = time.time()
        results   = self.model.train(data=str(yaml_path), **hp)
        elapsed_s = time.time() - t_start

        self._log.info(
            "Training finished in %.1fs  (%dm %ds)",
            elapsed_s, int(elapsed_s // 60), int(elapsed_s % 60),
        )

        self.save_dir = self._resolve_save_dir(results)
        best_pt       = self.save_dir / "weights" / "best.pt"

        if not best_pt.exists():
            last_pt = self.save_dir / "weights" / "last.pt"
            if last_pt.exists():
                best_pt = last_pt
                self._log.warning("best.pt absent — falling back to last.pt")

        self._log.info("Save dir   : %s", self.save_dir)
        self._log.info("Best model : %s", best_pt)
        self._log_epoch_table()
        return best_pt

    def _resolve_save_dir(self, results) -> Path:
        if results is not None and hasattr(results, "save_dir"):
            return Path(results.save_dir)
        if getattr(self.model, "trainer", None) is not None:
            if hasattr(self.model.trainer, "save_dir"):
                return Path(self.model.trainer.save_dir)
        named = Path(self.cfg.train_hp["project"]) / self.cfg.train_hp["name"]
        if named.exists():
            return named
        candidates = [d for d in Path(self.cfg.train_hp["project"]).iterdir() if d.is_dir()]
        if candidates:
            return max(candidates, key=lambda d: d.stat().st_mtime)
        raise FileNotFoundError(
            f"Cannot locate training output under {self.cfg.train_hp['project']}"
        )

    def _cb_epoch_start(self, trainer) -> None:
        self._epoch_start = time.time()

    def _cb_epoch_end(self, trainer) -> None:
        duration = time.time() - self._epoch_start
        self._epoch_times.append(duration)
        self._log.info(
            "Epoch %d/%d  —  wall-clock time: %.1fs  (%dm %ds)",
            trainer.epoch + 1, trainer.epochs,
            duration, int(duration // 60), int(duration % 60),
        )

    def _log_epoch_table(self) -> None:
        csv_path = self.save_dir / "results.csv"
        if not csv_path.exists():
            self._log.warning("results.csv not found — epoch log unavailable")
            return
        df = pd.read_csv(csv_path)
        df.columns = [c.strip() for c in df.columns]
        if self._epoch_times:
            n_rows = min(len(df), len(self._epoch_times))
            df.loc[: n_rows - 1, "epoch_time_s"] = [
                round(t, 1) for t in self._epoch_times[:n_rows]
            ]
            total_s = sum(self._epoch_times)
            self._log.info(
                "Total epoch wall-clock time: %.1fs  (%dm %ds)  | mean per epoch: %.1fs",
                total_s, int(total_s // 60), int(total_s % 60),
                total_s / len(self._epoch_times),
            )
        self._log.info(
            "Epoch-by-epoch training log:\n%s", df.round(4).to_string(index=False)
        )


# ════════════════════════════════════════════════════════════
#  CLASS 4 — YoloEvaluator
# ════════════════════════════════════════════════════════════
class YoloEvaluator:

    IOU_THRESHOLDS: np.ndarray = np.arange(0.5, 1.0, 0.05)

    def __init__(self, config: DatasetConfig, best_model_path: Path) -> None:
        self.cfg  = config
        self._log = logging.getLogger(f"{ROOT_LOG.name}.evaluator")

        self.model = YOLO(str(best_model_path))
        self._log.info("Best model loaded from %s", best_model_path)

        self.val_img_dir  = config.dataset_dir / "images"    / "validation"
        self.val_lbl_dir  = config.dataset_dir / "labels"    / "validation"
        self.val_mask_dir = config.dataset_dir / "seg_masks" / "validation"

        self.val_images: list = (
            sorted(self.val_img_dir.glob("*.jpg"))
            + sorted(self.val_img_dir.glob("*.png"))
        )
        self._log.info("Validation images available: %d", len(self.val_images))
        self._reset_accumulators()

        self._det_df: pd.DataFrame = None
        self._seg_df: pd.DataFrame = None
        self._roc_df: pd.DataFrame = None

    def run_inference(self) -> None:
        bs      = self.cfg.infer_batch_sz
        batches = [self.val_images[i: i + bs] for i in range(0, len(self.val_images), bs)]
        self._log.info(
            "Batched GPU inference — %d images, batch_size=%d, device=%s",
            len(self.val_images), bs, self.cfg.infer_device,
        )
        for batch_fps in tqdm(batches, desc="GPU inference"):
            batch_preds = self.model.predict(
                source  = [str(fp) for fp in batch_fps],
                imgsz   = self.cfg.train_hp["imgsz"],
                device  = self.cfg.infer_device,
                verbose = False,
                conf    = 0.1,
                stream  = False,
            )
            for img_fp, res in zip(batch_fps, batch_preds):
                self._accumulate_image(img_fp, res)
        self._log.info("Inference and metric accumulation complete.")

    def compute_detection_metrics(self) -> pd.DataFrame:
        n        = self.cfg.num_classes
        ap_table = np.zeros((n, len(self.IOU_THRESHOLDS)))
        for ci in range(n):
            for ti, iou_t in enumerate(self.IOU_THRESHOLDS):
                ap_table[ci, ti] = self._compute_ap(
                    self.per_class_preds[ci], self.per_class_gt_cnt[ci], iou_t,
                )
        self._ap_table = ap_table
        ap75_idx = min(5, len(self.IOU_THRESHOLDS) - 1)
        rows = []
        for ci in range(n):
            P, R, F1 = self._prf_at_conf(self.per_class_preds[ci], self.per_class_gt_cnt[ci])
            rows.append({
                "class"        : self.cfg.yolo_to_name[ci],
                "AP@0.50"      : round(ap_table[ci, 0],        4),
                "AP@0.75"      : round(ap_table[ci, ap75_idx], 4),
                "mAP@[.5:.95]" : round(ap_table[ci].mean(),    4),
                "Precision"    : round(P,  4),
                "Recall"       : round(R,  4),
                "F1"           : round(F1, 4),
            })
        df = pd.DataFrame(rows)
        macro = {
            "class"        : "Macro Average",
            "AP@0.50"      : round(df["AP@0.50"].mean(),       4),
            "AP@0.75"      : round(df["AP@0.75"].mean(),       4),
            "mAP@[.5:.95]" : round(df["mAP@[.5:.95]"].mean(), 4),
            "Precision"    : round(df["Precision"].mean(),     4),
            "Recall"       : round(df["Recall"].mean(),        4),
            "F1"           : round(df["F1"].mean(),            4),
        }
        self._det_df = pd.concat([df, pd.DataFrame([macro])], ignore_index=True)
        self._log.info("Detection metrics:\n%s", self._det_df.to_string(index=False))
        return self._det_df

    def compute_segmentation_metrics(self) -> pd.DataFrame:
        rows = []
        for ci in range(self.cfg.num_classes):
            ious  = self.sem_iou_per_class[ci]
            dices = self.sem_dice_per_class[ci]
            rows.append({
                "class"    : self.cfg.yolo_to_name[ci],
                "sem_pixel": ci + 1,
                "mIoU"     : round(np.mean(ious)  if ious  else 0.0, 4),
                "Dice"     : round(np.mean(dices) if dices else 0.0, 4),
                "n_images" : len(ious),
            })
        df = pd.DataFrame(rows)
        macro = {
            "class"    : "Macro Average",
            "sem_pixel": "—",
            "mIoU"     : round(df["mIoU"].mean(), 4),
            "Dice"     : round(df["Dice"].mean(), 4),
            "n_images" : "—",
        }
        self._seg_df = pd.concat([df, pd.DataFrame([macro])], ignore_index=True)
        self._log.info(
            "Segmentation metrics (background pixel=0 excluded):\n%s",
            self._seg_df.to_string(index=False),
        )
        return self._seg_df

    def compute_roc_auc(self, output_dir: Path) -> pd.DataFrame:
        n   = self.cfg.num_classes
        fig, axes = plt.subplots(1, n, figsize=(5 * n, 4))
        axes = [axes] if n == 1 else list(axes)
        rows = []
        for ci in range(n):
            yt   = np.array(self.y_true_det[ci])
            ys   = np.array(self.y_score_det[ci])
            ax   = axes[ci]
            name = self.cfg.yolo_to_name[ci]
            if yt.sum() == 0 or (1 - yt).sum() == 0:
                roc_auc = float("nan")
                ax.set_title(f"{name}\n(AUC undefined)")
            else:
                fpr, tpr, _ = roc_curve(yt, ys)
                roc_auc     = auc(fpr, tpr)
                ax.plot(fpr, tpr, lw=2, label=f"AUC = {roc_auc:.3f}")
                ax.plot([0, 1], [0, 1], "k--", lw=1)
                ax.set_xlabel("FPR"); ax.set_ylabel("TPR")
                ax.legend(); ax.set_xlim(0, 1); ax.set_ylim(0, 1)
                ax.set_title(name)
            rows.append({"class": name, "AUC": round(roc_auc, 4)})
        plt.suptitle("ROC Curves — Detection (per class)", fontsize=14)
        plt.tight_layout()
        roc_path = output_dir / "roc_curves_detection.png"
        plt.savefig(roc_path, dpi=120, bbox_inches="tight")
        plt.show()
        df = pd.DataFrame(rows)
        macro = {"class": "Macro Average", "AUC": round(float(np.nanmean(df["AUC"])), 4)}
        self._roc_df = pd.concat([df, pd.DataFrame([macro])], ignore_index=True)
        self._log.info("ROC AUC:\n%s", self._roc_df.to_string(index=False))
        self._log.info("ROC figure saved → %s", roc_path)
        return self._roc_df

    def plot_training_curves(self, trainer_save_dir: Path) -> None:
        csv_path = trainer_save_dir / "results.csv"
        if not csv_path.exists():
            self._log.warning("results.csv missing — skipping training curves")
            return
        df = pd.read_csv(csv_path)
        df.columns = [c.strip() for c in df.columns]
        metric_cols = [
            c for c in df.columns
            if any(k in c.lower() for k in ["loss", "map", "precision", "recall"])
        ]
        n_cols = min(4, len(metric_cols))
        n_rows = max(1, (len(metric_cols) + n_cols - 1) // n_cols)
        fig, axs = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
        axs      = np.array(axs).flatten()
        x_vals   = df.get("epoch", range(len(df)))
        for i, col in enumerate(metric_cols):
            axs[i].plot(x_vals, df[col])
            axs[i].set_title(col)
            axs[i].set_xlabel("Epoch")
        for j in range(i + 1, len(axs)):
            axs[j].axis("off")
        plt.suptitle("Training Metrics Over Epochs", fontsize=14)
        plt.tight_layout()
        out_path = self.cfg.results_dir / "training_curves.png"
        plt.savefig(out_path, dpi=120, bbox_inches="tight")
        plt.show()
        self._log.info("Training curves saved → %s", out_path)

    def plot_qualitative_predictions(self, n_samples: int = 6) -> None:
        sample_fps   = random.sample(self.val_images, min(n_samples, len(self.val_images)))
        qual_results = self.model.predict(
            source  = [str(fp) for fp in sample_fps],
            imgsz   = self.cfg.train_hp["imgsz"],
            device  = self.cfg.infer_device,
            verbose = False,
            conf    = 0.25,
        )
        cmap = plt.cm.get_cmap("tab10", self.cfg.num_classes)
        fig, axes = plt.subplots(2, 3, figsize=(18, 12))
        axes      = axes.flatten()
        for ax_idx, (fp, res) in enumerate(zip(sample_fps, qual_results)):
            ax     = axes[ax_idx]
            img_np = np.array(Image.open(fp).convert("RGB"))
            ax.imshow(img_np)
            if res.boxes is not None:
                boxes   = res.boxes
                masks_r = res.masks
                for idx in range(len(boxes)):
                    cls_id = int(boxes.cls[idx])
                    conf   = float(boxes.conf[idx])
                    xyxy   = boxes.xyxy[idx].cpu().numpy()
                    color  = cmap(cls_id)
                    ax.add_patch(patches.Rectangle(
                        (xyxy[0], xyxy[1]), xyxy[2] - xyxy[0], xyxy[3] - xyxy[1],
                        linewidth=2, edgecolor=color, facecolor="none",
                    ))
                    ax.text(
                        xyxy[0], xyxy[1] - 4,
                        f"{self.cfg.yolo_to_name.get(cls_id, '?')}  {conf:.2f}",
                        color="white", fontsize=8,
                        bbox=dict(facecolor=color, alpha=0.7, pad=1),
                    )
                    if masks_r is not None and idx < len(masks_r.xy):
                        poly_pts = np.array(masks_r.xy[idx])
                        if len(poly_pts) >= 3:
                            ax.add_patch(patches.Polygon(
                                poly_pts, closed=True, facecolor=color, alpha=0.35,
                            ))
            ax.axis("off")
            ax.set_title(fp.stem, fontsize=9)
        plt.suptitle("YOLO Predictions on Validation Set", fontsize=14)
        plt.tight_layout()
        vis_path = self.cfg.results_dir / "qualitative_predictions.png"
        plt.savefig(vis_path, dpi=120, bbox_inches="tight")
        plt.show()
        self._log.info("Qualitative visualisation saved → %s", vis_path)

    def plot_per_class_bar_chart(self) -> None:
        n           = self.cfg.num_classes
        names_short = [self.cfg.yolo_to_name[i][:13] for i in range(n)]
        det = self._det_df[self._det_df["class"] != "Macro Average"].reset_index(drop=True)
        seg = self._seg_df[self._seg_df["class"] != "Macro Average"].reset_index(drop=True)
        x, w = np.arange(n), 0.15
        fig, ax = plt.subplots(figsize=(max(10, 2 * n), 5))
        ax.bar(x - 2 * w, det["Precision"],   w, label="Precision",  color="steelblue")
        ax.bar(x -     w, det["Recall"],       w, label="Recall",     color="darkorange")
        ax.bar(x,         det["F1"],            w, label="F1",         color="green")
        ax.bar(x +     w, det["mAP@[.5:.95]"], w, label="mAP@.5:.95", color="red")
        ax.bar(x + 2 * w, seg["mIoU"],          w, label="mIoU",       color="purple")
        ax.set_xticks(x)
        ax.set_xticklabels(names_short, rotation=30, ha="right")
        ax.set_ylim(0, 1.05)
        ax.set_ylabel("Score")
        ax.set_title("Per-Class Metrics — Detection & Segmentation")
        ax.legend(loc="upper right", fontsize=8)
        plt.tight_layout()
        bar_path = self.cfg.results_dir / "per_class_metrics.png"
        plt.savefig(bar_path, dpi=120, bbox_inches="tight")
        plt.show()
        self._log.info("Per-class bar chart saved → %s", bar_path)

    def print_final_summary(self, n_train: int, n_val: int) -> None:
        cfg = self.cfg
        hp  = cfg.train_hp
        self._log.info("=== FINAL METRICS SUMMARY ===")
        self._log.info(
            "GPU(s): %d× %s  |  train=%d  val=%d  epochs=%d  imgsz=%d  batch=%d",
            cfg.num_gpus, cfg.gpu_names[0] if cfg.gpu_names else "CPU",
            n_train, n_val, hp["epochs"], hp["imgsz"], hp["batch"],
        )
        summary = (
            self._det_df
            .merge(self._seg_df[["class", "mIoU", "Dice"]], on="class", how="left")
            .merge(self._roc_df, on="class", how="left")
        )
        self._log.info("Full per-class summary:\n%s", summary.to_string(index=False))
        self._log.info("Semantic mask pixel legend:")
        self._log.info("  pixel 0 = background (unannotated)")
        for ci in range(cfg.num_classes):
            self._log.info(
                "  pixel %d = %s  (YOLO class %d)", ci + 1, cfg.yolo_to_name[ci], ci,
            )
        self._log.info("Outputs saved to: %s", cfg.results_dir)

    # ── Private: accumulators ─────────────────────────────────

    def _reset_accumulators(self) -> None:
        n = self.cfg.num_classes
        self.per_class_preds:    dict = {c: [] for c in range(n)}
        self.per_class_gt_cnt:   dict = {c: 0  for c in range(n)}
        self.sem_iou_per_class:  dict = {c: [] for c in range(n)}
        self.sem_dice_per_class: dict = {c: [] for c in range(n)}
        self.y_true_det:         dict = {c: [] for c in range(n)}
        self.y_score_det:        dict = {c: [] for c in range(n)}

    def _accumulate_image(self, img_fp: Path, res) -> None:
        pil_img = Image.open(img_fp)
        W, H    = pil_img.size
        stem    = img_fp.stem
        gts     = self._load_ground_truth(stem, W, H)
        if not gts:
            return
        gt_labels_set = {g["label"] for g in gts}
        gt_by_cls     = defaultdict(list)
        for g in gts:
            gt_by_cls[g["label"]].append(g)
            self.per_class_gt_cnt[g["label"]] += 1
        preds = self._extract_preds(res)
        pred_max_conf = defaultdict(float)
        for p in preds:
            pred_max_conf[p["cls"]] = max(pred_max_conf[p["cls"]], p["conf"])
        for c in range(self.cfg.num_classes):
            self.y_true_det[c].append(1 if c in gt_labels_set else 0)
            self.y_score_det[c].append(pred_max_conf.get(c, 0.0))
        for p in sorted(preds, key=lambda x: x["conf"], reverse=True):
            c        = p["cls"]
            best_iou = max(
                (self._iou_boxes(p["bbox"], gt["bbox"]) for gt in gt_by_cls.get(c, [])),
                default=0.0,
            )
            self.per_class_preds[c].append((p["conf"], best_iou))
        gt_mask_fp = self.val_mask_dir / f"{stem}.png"
        if not gt_mask_fp.exists():
            return
        gt_sem   = np.array(Image.open(gt_mask_fp))
        pred_sem = np.zeros((H, W), dtype=np.uint8)
        for p in preds:
            if p["conf"] < 0.25 or p["poly"] is None:
                continue
            sem_idx = p["cls"] + 1
            poly_np = np.array(p["poly"], dtype=np.int32).reshape((-1, 1, 2))
            poly_np[..., 0] = np.clip(poly_np[..., 0], 0, W - 1)
            poly_np[..., 1] = np.clip(poly_np[..., 1], 0, H - 1)
            cv2.fillPoly(pred_sem, [poly_np], int(sem_idx))
        for ci in range(self.cfg.num_classes):
            sem_idx  = ci + 1
            gt_bin   = (gt_sem   == sem_idx).astype(np.uint8)
            pred_bin = (pred_sem == sem_idx).astype(np.uint8)
            if gt_bin.sum() == 0:
                continue
            self.sem_iou_per_class[ci].append(self._iou_masks(pred_bin, gt_bin))
            self.sem_dice_per_class[ci].append(self._dice_masks(pred_bin, gt_bin))

    def _load_ground_truth(self, img_stem: str, img_w: int, img_h: int) -> list:
        lbl_fp = self.val_lbl_dir / f"{img_stem}.txt"
        if not lbl_fp.exists():
            return []
        gts = []
        for line in lbl_fp.read_text().splitlines():
            parts = line.strip().split()
            if not parts:
                continue
            cls  = int(parts[0])
            pts  = list(map(float, parts[1:]))
            poly = [(pts[i] * img_w, pts[i + 1] * img_h) for i in range(0, len(pts) - 1, 2)]
            xs   = [p[0] for p in poly]
            ys   = [p[1] for p in poly]
            gts.append({"label": cls, "bbox": [min(xs), min(ys), max(xs), max(ys)], "poly": poly})
        return gts

    @staticmethod
    def _extract_preds(res) -> list:
        preds = []
        if res.boxes is None:
            return preds
        boxes   = res.boxes
        masks_r = res.masks
        for idx in range(len(boxes)):
            poly = (
                masks_r.xy[idx].tolist()
                if masks_r is not None and idx < len(masks_r.xy)
                else None
            )
            preds.append({
                "cls" : int(boxes.cls[idx]),
                "conf": float(boxes.conf[idx]),
                "bbox": boxes.xyxy[idx].cpu().numpy().tolist(),
                "poly": poly,
            })
        return preds

    @staticmethod
    def _iou_boxes(b1: list, b2: list) -> float:
        xi1 = max(b1[0], b2[0]); yi1 = max(b1[1], b2[1])
        xi2 = min(b1[2], b2[2]); yi2 = min(b1[3], b2[3])
        inter = max(0.0, xi2 - xi1) * max(0.0, yi2 - yi1)
        a1    = (b1[2] - b1[0]) * (b1[3] - b1[1])
        a2    = (b2[2] - b2[0]) * (b2[3] - b2[1])
        denom = a1 + a2 - inter
        return inter / denom if denom > 0 else 0.0

    @staticmethod
    def _iou_masks(m1: np.ndarray, m2: np.ndarray) -> float:
        inter = np.logical_and(m1, m2).sum()
        union = np.logical_or(m1,  m2).sum()
        return float(inter / union) if union > 0 else 0.0

    @staticmethod
    def _dice_masks(m1: np.ndarray, m2: np.ndarray) -> float:
        inter = np.logical_and(m1, m2).sum()
        denom = m1.sum() + m2.sum()
        return float(2 * inter / denom) if denom > 0 else 0.0

    @staticmethod
    def _compute_ap(preds_list: list, n_gt: int, iou_thresh: float = 0.5) -> float:
        if n_gt == 0 or not preds_list:
            return 0.0
        sorted_preds = sorted(preds_list, key=lambda x: x[0], reverse=True)
        tp     = np.array([1.0 if iou >= iou_thresh else 0.0 for _, iou in sorted_preds])
        cum_tp = np.cumsum(tp)
        cum_fp = np.cumsum(1.0 - tp)
        prec   = cum_tp / (cum_tp + cum_fp + 1e-9)
        rec    = cum_tp / (n_gt + 1e-9)
        return sum(
            (float(np.max(prec[rec >= r])) if (rec >= r).any() else 0.0) / 11.0
            for r in np.linspace(0.0, 1.0, 11)
        )

    @staticmethod
    def _prf_at_conf(
        preds_list: list, n_gt: int,
        conf_thresh: float = 0.25, iou_thresh: float = 0.50,
    ) -> tuple:
        filtered = [(c, iou) for c, iou in preds_list if c >= conf_thresh]
        tp = sum(1 for _, iou in filtered if iou >= iou_thresh)
        fp = len(filtered) - tp
        fn = max(0, n_gt - tp)
        P  = tp / (tp + fp + 1e-9)
        R  = tp / (tp + fn + 1e-9)
        F1 = 2.0 * P * R / (P + R + 1e-9)
        return P, R, F1


# ════════════════════════════════════════════════════════════
#  ENTRY POINT
# ════════════════════════════════════════════════════════════
def main() -> None:
    log = logging.getLogger(f"{ROOT_LOG.name}.main")

    log.info("Initialising DatasetConfig …")
    config = DatasetConfig()
    config.log_summary()

    log.info("Building YOLO dataset …")
    builder = YoloDataBuilder(config)
    n_train, n_val = builder.build_all()
    builder.compute_class_weights()

    yaml_path = config.generate_yaml()

    trainer = YoloTrainer(config)
    trainer.load_pretrained()
    best_model_path = trainer.train(yaml_path)

    evaluator = YoloEvaluator(config, best_model_path)
    evaluator.run_inference()
    evaluator.compute_detection_metrics()
    evaluator.compute_segmentation_metrics()
    evaluator.compute_roc_auc(config.results_dir)
    evaluator.plot_training_curves(trainer.save_dir)
    evaluator.plot_qualitative_predictions()
    evaluator.plot_per_class_bar_chart()
    evaluator.print_final_summary(n_train, n_val)

    log.info("ALL DONE.  Best model → %s", best_model_path)
    log.info("Outputs   → %s", config.results_dir)


if __name__ == "__main__":
    main()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.8 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 19:12:36  [INFO    ]  yolo_fashion.main — Initialising DatasetConfig …
# 19:12:36  [INFO    ]  yolo_fashion.config — GPU inventory: 2  ['Tesla T4', 'Tesla T4']
# 19:12:36  [INFO    ]  yolo_fashion.config — Devices — train: 0,1  infer: 0
# 19:12:36  [INFO    ]  yolo_fashion.config — Class mapping:
#  yolo_idx  df2_cat  sem_pixel             name
#         0        1          1 short_sleeve_top
#         1        8          2         trousers
#         2        7          3           shorts
#         3        2          4  long_sleeve_top
#         4        9          5            skirt
# 19:12:36  [INFO    ]  yolo_fashion.config — Hyperparameters:
#     parameter                                         value
#        epochs                                            15
#         imgsz                                           640
#         batch                                            32
#       workers                                             4
#        device                                           0,1
#      patience                                             5
#           lr0                                       0.00001
#           lrf                                          0.01
#      momentum                                         0.937
#  weight_decay                                        0.0005
# warmup_epochs                                             1
#        cos_lr                                          True
#           amp                                          True
#         cache                                          disk
#       augment                                          True
#        mosaic                                           1.0
#         mixup                                           0.1
#    copy_paste                                           0.0
#       degrees                                          10.0
#     translate                                           0.1
#         scale                                           0.5
#        fliplr                                           0.5
#         hsv_h                                         0.015
#         hsv_s                                           0.7
#         hsv_v                                           0.4
#       verbose                                          True
#         plots                                          True
#          save                                          True
#       project /kaggle/working/yolo_fashion_finetune/results
#          name                         yolo_fashion_finetune
#      exist_ok                                          True
#    pretrained                                          True
#        freeze                                            10
# 19:12:36  [INFO    ]  yolo_fashion.main — Building YOLO dataset …
# 19:12:40  [INFO    ]  yolo_fashion.builder — [train] 144174 annotation files found in /kaggle/input/datasets/shubhranilbasak/vr-trimmed-dataset/Trimmed-vr-dataset/DeepFashion2_Top5_train/annos
#   Building [train]: 100%|██████████| 144174/144174 [19:30<00:00, 123.16it/s]
# 19:32:17  [INFO    ]  yolo_fashion.builder — [train] written=144174  skipped=0
# 19:32:18  [INFO    ]  yolo_fashion.builder — [validation] 23741 annotation files found in /kaggle/input/datasets/shubhranilbasak/vr-trimmed-dataset/Trimmed-vr-dataset/DeepFashion2_Top5_val/annos
#   Building [validation]: 100%|██████████| 23741/23741 [03:16<00:00, 120.52it/s]
# 19:35:36  [INFO    ]  yolo_fashion.builder — [validation] written=23741  skipped=0
# 19:35:36  [INFO    ]  yolo_fashion.builder — Dataset build complete.  train=144174  val=23741
# 19:36:05  [INFO    ]  yolo_fashion.builder — Class weights:
#  yolo_idx       class_name   count  weight
#         0 short_sleeve_top 71645.0  0.5841
#         1         trousers 55387.0  0.7555
#         2           shorts 36616.0  1.1429
#         3  long_sleeve_top 36064.0  1.1604
#         4            skirt 30835.0  1.3571
# 19:36:05  [INFO    ]  yolo_fashion.config — dataset.yaml → /kaggle/working/yolo_fashion_finetune/dataset/dataset.yaml
# 19:36:05  [INFO    ]  yolo_fashion.config — Classes (5): ['short_sleeve_top', 'trousers', 'shorts', 'long_sleeve_top', 'skirt']
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n-seg.pt to 'yolov8n-seg.pt': 100% ━━━━━━━━━━━━ 6.7MB 77.4MB/s 0.1s
# 19:36:06  [INFO    ]  yolo_fashion.trainer — Loaded yolov8n-seg.pt  (3,409,968 parameters)
# 19:36:06  [INFO    ]  yolo_fashion.trainer — Strategy: FINE-TUNING — COCO pretrained, 10 backbone layers frozen, lr=1e-05
# 19:36:06  [INFO    ]  yolo_fashion.trainer — Epoch-timing callbacks registered.
# 19:36:06  [INFO    ]  yolo_fashion.trainer — Training configuration:
#     parameter                                         value
#        epochs                                            15
#         imgsz                                           640
#         batch                                            32
#       workers                                             4
#        device                                           0,1
#      patience                                             5
#           lr0                                       0.00001
#           lrf                                          0.01
#      momentum                                         0.937
#  weight_decay                                        0.0005
# warmup_epochs                                             1
#        cos_lr                                          True
#           amp                                          True
#         cache                                          disk
#       augment                                          True
#        mosaic                                           1.0
#         mixup                                           0.1
#    copy_paste                                           0.0
#       degrees                                          10.0
#     translate                                           0.1
#         scale                                           0.5
#        fliplr                                           0.5
#         hsv_h                                         0.015
#         hsv_s                                           0.7
#         hsv_v                                           0.4
#       verbose                                          True
#         plots                                          True
#          save                                          True
#       project /kaggle/working/yolo_fashion_finetune/results
#          name                         yolo_fashion_finetune
#      exist_ok                                          True
#    pretrained                                          True
#        freeze                                            10
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/yolo_fashion_finetune/dataset/dataset.yaml, degrees=10.0, deterministic=True, device=0,1, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=15, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=10, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=1e-05, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo_fashion_finetune, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_fashion_finetune/results, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_fashion_finetune/results/yolo_fashion_finetune, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=1, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1005055  ultralytics.nn.modules.head.Segment          [5, 32, 64, 16, None, [64, 128, 256]]
# YOLOv8n-seg summary: 152 layers, 3,264,591 parameters, 3,264,575 gradients, 11.5 GFLOPs
#
# Transferred 381/417 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 35093 /root/.config/Ultralytics/DDP/_temp__825ehv8136059221708912.py
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# Overriding model.yaml nc=80 with nc=5
# Transferred 381/417 items from pretrained weights
# Freezing layer 'model.0.conv.weight'
# Freezing layer 'model.0.bn.weight'
# Freezing layer 'model.0.bn.bias'
# Freezing layer 'model.1.conv.weight'
# Freezing layer 'model.1.bn.weight'
# Freezing layer 'model.1.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.conv.weight'
# Freezing layer 'model.2.cv2.bn.weight'
# Freezing layer 'model.2.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.cv2.bn.bias'
# Freezing layer 'model.3.conv.weight'
# Freezing layer 'model.3.bn.weight'
# Freezing layer 'model.3.bn.bias'
# Freezing layer 'model.4.cv1.conv.weight'
# Freezing layer 'model.4.cv1.bn.weight'
# Freezing layer 'model.4.cv1.bn.bias'
# Freezing layer 'model.4.cv2.conv.weight'
# Freezing layer 'model.4.cv2.bn.weight'
# Freezing layer 'model.4.cv2.bn.bias'
# Freezing layer 'model.4.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.0.cv2.bn.bias'
# Freezing layer 'model.4.m.1.cv1.conv.weight'
# Freezing layer 'model.4.m.1.cv1.bn.weight'
# Freezing layer 'model.4.m.1.cv1.bn.bias'
# Freezing layer 'model.4.m.1.cv2.conv.weight'
# Freezing layer 'model.4.m.1.cv2.bn.weight'
# Freezing layer 'model.4.m.1.cv2.bn.bias'
# Freezing layer 'model.5.conv.weight'
# Freezing layer 'model.5.bn.weight'
# Freezing layer 'model.5.bn.bias'
# Freezing layer 'model.6.cv1.conv.weight'
# Freezing layer 'model.6.cv1.bn.weight'
# Freezing layer 'model.6.cv1.bn.bias'
# Freezing layer 'model.6.cv2.conv.weight'
# Freezing layer 'model.6.cv2.bn.weight'
# Freezing layer 'model.6.cv2.bn.bias'
# Freezing layer 'model.6.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.1.cv1.conv.weight'
# Freezing layer 'model.6.m.1.cv1.bn.weight'
# Freezing layer 'model.6.m.1.cv1.bn.bias'
# Freezing layer 'model.6.m.1.cv2.conv.weight'
# Freezing layer 'model.6.m.1.cv2.bn.weight'
# Freezing layer 'model.6.m.1.cv2.bn.bias'
# Freezing layer 'model.7.conv.weight'
# Freezing layer 'model.7.bn.weight'
# Freezing layer 'model.7.bn.bias'
# Freezing layer 'model.8.cv1.conv.weight'
# Freezing layer 'model.8.cv1.bn.weight'
# Freezing layer 'model.8.cv1.bn.bias'
# Freezing layer 'model.8.cv2.conv.weight'
# Freezing layer 'model.8.cv2.bn.weight'
# Freezing layer 'model.8.cv2.bn.bias'
# Freezing layer 'model.8.m.0.cv1.conv.weight'
# Freezing layer 'model.8.m.0.cv1.bn.weight'
# Freezing layer 'model.8.m.0.cv1.bn.bias'
# Freezing layer 'model.8.m.0.cv2.conv.weight'
# Freezing layer 'model.8.m.0.cv2.bn.weight'
# Freezing layer 'model.8.m.0.cv2.bn.bias'
# Freezing layer 'model.9.cv1.conv.weight'
# Freezing layer 'model.9.cv1.bn.weight'
# Freezing layer 'model.9.cv1.bn.bias'
# Freezing layer 'model.9.cv2.conv.weight'
# Freezing layer 'model.9.cv2.bn.weight'
# Freezing layer 'model.9.cv2.bn.bias'
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 63.7MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 758.7±893.1 MB/s, size: 76.7 KB)
# train: Scanning /kaggle/working/yolo_fashion_finetune/dataset/labels/train... 144174 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 144174/144174 820.0it/s 2:56
# train: New cache created: /kaggle/working/yolo_fashion_finetune/dataset/labels/train.cache
# WARNING ⚠️ train: 315.2GB disk space required, with 50% safety margin but only 9.1/19.5GB free, not caching images to disk
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 648.1±202.5 MB/s, size: 55.3 KB)
# val: Scanning /kaggle/working/yolo_fashion_finetune/dataset/labels/validation... 23741 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 23741/23741 1.1Kit/s 22.5s
# val: New cache created: /kaggle/working/yolo_fashion_finetune/dataset/labels/validation.cache
# WARNING ⚠️ val: 47.7GB disk space required, with 50% safety margin but only 9.0/19.5GB free, not caching images to disk
# optimizer: 'optimizer=auto' found, ignoring 'lr0=1e-05' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias(decay=0.0)
# Plotting labels to /kaggle/working/yolo_fashion_finetune/results/yolo_fashion_finetune/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_fashion_finetune/results/yolo_fashion_finetune
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        1/15      1.91G     0.9672      2.337      1.581      1.232          0         35        640: 100% ━━━━━━━━━━━━ 4506/4506 2.2it/s 34:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.4it/s 2:35
#                    all      23741      38797      0.699      0.733      0.766      0.584      0.697      0.726      0.758       0.54
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        2/15      3.61G     0.9191      2.183      1.159      1.189          0         34        640: 100% ━━━━━━━━━━━━ 4506/4506 2.3it/s 32:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.4it/s 2:35
#                    all      23741      38797       0.77      0.782      0.825      0.661      0.767      0.774      0.815      0.607
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        3/15      3.61G     0.8609      2.083      1.058       1.15          0         22        640: 100% ━━━━━━━━━━━━ 4506/4506 2.3it/s 32:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.4it/s 2:34
#                    all      23741      38797      0.798      0.798       0.84      0.683      0.794      0.791      0.831      0.625
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        4/15      3.61G     0.8378      2.054      1.016      1.135          0         28        640: 100% ━━━━━━━━━━━━ 4506/4506 2.3it/s 32:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.5it/s 2:29
#                    all      23741      38797      0.805      0.816      0.855      0.702      0.801       0.81      0.846      0.643
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        5/15      3.61G     0.8239      2.024     0.9904      1.126          0         26        640: 100% ━━━━━━━━━━━━ 4506/4506 2.4it/s 31:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.5it/s 2:27
#                    all      23741      38797      0.811      0.824       0.86      0.709      0.807      0.819      0.852      0.651
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        6/15      3.62G     0.7062      1.638     0.6901      1.079          0         12        640: 100% ━━━━━━━━━━━━ 4506/4506 2.7it/s 27:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.6it/s 2:25
#                    all      23741      38797      0.823      0.835       0.87      0.723      0.822      0.827      0.862      0.664
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        7/15      3.62G     0.6894      1.602     0.6592      1.066          0         12        640: 100% ━━━━━━━━━━━━ 4506/4506 2.7it/s 27:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 371/371 2.5it/s 2:30
#                    all      23741      38797      0.826      0.838      0.874      0.729      0.823      0.832      0.866      0.668
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#
#            skirt         5 0.7297 0.7768     6499
#    Macro Average         — 0.7014 0.7647        —
# 03:54:10  [INFO    ]  yolo_fashion.evaluator — ROC AUC:
#            class    AUC
# short_sleeve_top 0.9584
#         trousers 0.9713
#           shorts 0.9283
#  long_sleeve_top 0.9333
#            skirt 0.9477
#    Macro Average 0.9478
# 03:54:10  [INFO    ]  yolo_fashion.evaluator — ROC figure saved → /kaggle/working/yolo_fashion_finetune/results/roc_curves_detection.png
# 03:54:15  [INFO    ]  yolo_fashion.evaluator — Training curves saved → /kaggle/working/yolo_fashion_finetune/results/training_curves.png
# /tmp/ipykernel_24/1010947442.py:668: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", self.cfg.num_classes)
# 03:54:18  [INFO    ]  yolo_fashion.evaluator — Qualitative visualisation saved → /kaggle/working/yolo_fashion_finetune/results/qualitative_predictions.png
# 03:54:18  [INFO    ]  yolo_fashion.evaluator — Per-class bar chart saved → /kaggle/working/yolo_fashion_finetune/results/per_class_metrics.png
# 03:54:18  [INFO    ]  yolo_fashion.evaluator — === FINAL METRICS SUMMARY ===
# 03:54:18  [INFO    ]  yolo_fashion.evaluator — GPU(s): 2× Tesla T4  |  train=144174  val=23741  epochs=15  imgsz=640  batch=32
# 03:54:18  [INFO    ]  yolo_fashion.evaluator — Full per-class summary:
#            class  AP@0.50  AP@0.75  mAP@[.5:.95]  Precision  Recall     F1   mIoU   Dice    AUC
# short_sleeve_top   0.8863   0.8767        0.8129     0.8405  0.9525 0.8930 0.7861 0.8456 0.9584
#         trousers   0.8451   0.7551        0.6817     0.8211  0.9248 0.8698 0.7002 0.7845 0.9713
#           shorts   0.7871   0.7726        0.6389     0.7856  0.8503 0.8166 0.6290 0.6963 0.9283
#  long_sleeve_top   0.7205   0.6980        0.6249     0.7200  0.8456 0.7778 0.6618 0.7205 0.9333
#            skirt   0.8540   0.7750        0.7239     0.8129  0.8999 0.8542 0.7297 0.7768 0.9477
#    Macro Average   0.8186   0.7755        0.6965     0.7960  0.8946 0.8423 0.7014 0.7647 0.9478
# 03:54:18  [INFO    ]  yolo_fashion.evaluator — Semantic mask pixel legend:
# 03:54:18  [INFO    ]  yolo_fashion.evaluator —   pixel 0 = background (unannotated)
# 03:54:18  [INFO    ]  yolo_fashion.evaluator —   pixel 1 = short_sleeve_top  (YOLO class 0)
# 03:54:18  [INFO    ]  yolo_fashion.evaluator —   pixel 2 = trousers  (YOLO class 1)
# 03:54:18  [INFO    ]  yolo_fashion.evaluator —   pixel 3 = shorts  (YOLO class 2)
# 03:54:18  [INFO    ]  yolo_fashion.evaluator —   pixel 4 = long_sleeve_top  (YOLO class 3)
# 03:54:18  [INFO    ]  yolo_fashion.evaluator —   pixel 5 = skirt  (YOLO class 4)
# 03:54:18  [INFO    ]  yolo_fashion.evaluator — Outputs saved to: /kaggle/working/yolo_fashion_finetune/results
# 03:54:18  [INFO    ]  yolo_fashion.main — ALL DONE.  Best model → /kaggle/working/yolo_fashion_finetune/results/yolo_fashion_finetune/weights/best.pt
# 03:54:18  [INFO    ]  yolo_fashion.main — Outputs   → /kaggle/working/yolo_fashion_finetune/results
